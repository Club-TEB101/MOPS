# %%
import requests
from requests.adapters import HTTPAdapter
from bs4 import BeautifulSoup as bs4

header= {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.106 Safari/537.36'}
url='https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=2330&SYEAR=2019&SSEASON=2&REPORT_ID=C'


web_ss = requests.session()
ss_adapter = HTTPAdapter(max_retries=3)
web_ss.mount("https://", adapter=ss_adapter)
res = web_ss.get(url=url, headers=header)
res.encoding = 'big5'
if res.status_code == 200:
    #soup = bs4(res.text, "lxml")
    soup = bs4(res.text, "html.parser")
    tables = soup.select('table')
#print(tables)

# %%
Ntable = 0
start = 6
k = 3

code = tables[Ntable].select('td')

code_list=[]

for _code in code:
    try:
        if (_code['style'])!='':
            code_list.append(_code.text)
    except:
        pass
#print(code_list)

cht = tables[Ntable].select('span.zh')
en = tables[Ntable].select('span.en')
amt = tables[Ntable].select('td.amt')

#print(code)
#print(len(cht[start:]), len(amt)/k)
#df_cht, df_eng = {} , {}

Balance_list=[]
j=0
for i, _amt in enumerate(amt):
    
    if i%k==0:
        #print(i, _amt.text)
        #balance_list[code_list[j]]= [{'cht':cht[6+j].text.strip(),'value':_amt.text.strip().replace(',','')}]
        Balance_list.append([{'code':code_list[j], 'en':en[start+j].text.strip(), 'cht':cht[start+j].text.strip()
                              ,'value':_amt.text.strip().replace(',','')}])
        j+=1

Balance={'Balance':Balance_list}        
#print(Balance)

# %%
Ntable = 1
k = 4
start=7


code = tables[Ntable].select('td')

code_list=[]

for _code in code:
    try:
        if (_code['style'])!='':
            code_list.append(_code.text)
    except:
        pass
#print(code_list)

cht = tables[Ntable].select('span.zh')
en = tables[Ntable].select('span.en')
amt = tables[Ntable].select('td.amt')

#print(code)

#print(len(cht[7:]), len(amt)/4)

ProfitLoss_list=[]
j=0
for i, _amt in enumerate(amt):
    
    if i%4==0:
        ProfitLoss_list.append([{'code':code_list[j], 'en':en[start+j].text.strip(), 'cht':cht[start+j].text.strip(),
                              'value':_amt.text.strip().replace(',','')}])
        j+=1

ProfitLoss={'ProfitLoss':profit_loss_list}        
#print(ProfitLoss)

# %%
Ntable = 2
start=5
k=2


code = tables[Ntable].select('td')


code_list=[]

for _code in code:
    try:
        if (_code['style'])!='':
            code_list.append(_code.text)
    except:
        pass
#print(code_list)

cht = tables[Ntable].select('span.zh')
en = tables[Ntable].select('span.en')
amt = tables[Ntable].select('td.amt')

#print(code)

#print(len(cht[start:]), len(amt)/2)

CashFlows_list=[]
j=0
for i, _amt in enumerate(amt):
    
    if i%k==0:
        CashFlows_list.append([{'code':code_list[j], 'en':en[start+j].text.strip(), 'cht':cht[start+j].text.strip(),
                              'value':_amt.text.strip().replace(',','')}])
        j+=1

CashFlows={'CashFlows':CashFlows_list}        
#print(CashFlows)

# %%
Ntable = 3
start=5
k=2

Etable = tables[Ntable]
print(Etable)
# Out:
# <table style="width:150%">
# <tr>
# <th colspan="31">
# <span class="zh">當期權益變動表</span><span class="en">Statements of Change in Equity</span>
# </th>
# </tr>
# <tr>
# <th colspan="2" rowspan="2"></th>
# <th>3110</th>
# <th>3100</th>
# <th>3200</th>
# <th>3310</th>
# <th>3320</th>
# <th>3350</th>
# <th>3300</th>
# <th>3410</th>
# <th>3420</th>
# <th>3450</th>
# <th>3490</th>
# <th>3400</th>
# <th>31XX</th>
# <th>36XX</th>
# <th>3XXX</th>
# </tr>
# <tr>
# <th>
# <span class="zh">普通股股本</span>
# <span class="en">　　　　　Ordinary share</span>
# </th>
# <th>
# <span class="zh">股本合計</span>
# <span class="en">　　　　Total share capital</span>
# </th>
# <th>
# <span class="zh">資本公積</span>
# <span class="en">　　　　Capital surplus</span>
# </th>
# <th>
# <span class="zh">法定盈餘公積</span>
# <span class="en">　　　　　Legal reserve</span>
# </th>
# <th>
# <span class="zh">特別盈餘公積</span>
# <span class="en">　　　　　Special reserve</span>
# </th>
# <th>
# <span class="zh">未分配盈餘（或待彌補虧損）</span>
# <span class="en">　　　　　Unappropriated retained earnings (accumulated deficit)</span>
# </th>
# <th>
# <span class="zh">保留盈餘合計</span>
# <span class="en">　　　　Total retained earnings</span>
# </th>
# <th>
# <span class="zh">國外營運機構財務報表換算之兌換差額</span>
# <span class="en">　　　　　Exchange differences on translation of foreign financial statements</span>
# </th>
# <th>
# <span class="zh">透過其他綜合損益按公允價值衡量之金融資產未實現評價(損)益</span>
# <span class="en">　　　　　Unrealised gains (losses) on financial assets measured at fair value through other comprehensive income</span>
# </th>
# <th>
# <span class="zh">避險工具之利益（損失）</span>
# <span class="en">　　　　　Gains (losses) on hedging instruments</span>
# </th>
# <th>
# <span class="zh">其他</span>
# <span class="en">　　　　　Others</span>
# </th>
# <th>
# <span class="zh">其他權益項目合計</span>
# <span class="en">　　　　Total other equity interest</span>
# </th>
# <th>
# <span class="zh">歸屬於母公司業主之權益總計</span>
# <span class="en">　　　Total equity attributable to owners of parent</span>
# </th>
# <th>
# <span class="zh">非控制權益</span>
# <span class="en">　　　Non-controlling interests</span>
# </th>
# <th>
# <span class="zh">權益總額</span>
# <span class="en">　　Total equity</span>
# </th>
# </tr>
# <tr>
# <td>A1</td>
# <td>
# <span class="zh">期初餘額</span>
# <span class="en">　Equity at beginning of period</span>
# </td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20190101_OrdinaryShareMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:Equity" scale="3" unitref="TWD">259,303,805</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20190101_IssuedCapitalMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:Equity" scale="3" unitref="TWD">259,303,805</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20190101_CapitalReserveMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:Equity" scale="3" unitref="TWD">56,315,932</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20190101_StatutoryReserveMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:Equity" scale="3" unitref="TWD">276,033,811</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20190101_SpecialReserveMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:Equity" scale="3" unitref="TWD">26,907,527</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20190101_UnappropriatedRetainedEarningsAccumulatedDeficitMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:Equity" scale="3" unitref="TWD">1,073,706,503</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20190101_RetainedEarningsMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:Equity" scale="3" unitref="TWD">1,376,647,841</ix:nonfraction> </pre></td>
# <td class="amt"><pre>(<ix:nonfraction contextref="AsOf20190101_ReserveOfExchangeDifferencesOnTranslationMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:Equity" scale="3" sign="-" unitref="TWD">12,042,347</ix:nonfraction>)</pre></td>
# <td class="amt"><pre>(<ix:nonfraction contextref="AsOf20190101_ReserveOfGainsAndLossesOnFinancialAssetsMeasuredAtFairValueThroughOtherComprehensiveIncomeMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:Equity" scale="3" sign="-" unitref="TWD">3,429,324</ix:nonfraction>)</pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20190101_GainsLossesOnHedgingInstrumentsMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:Equity" scale="3" unitref="TWD">23,601</ix:nonfraction> </pre></td>
# <td class="amt"><pre>(<ix:nonfraction contextref="AsOf20190101_Others-OtherEquityInterestMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:Equity" scale="3" sign="-" unitref="TWD">1,843</ix:nonfraction>)</pre></td>
# <td class="amt"><pre>(<ix:nonfraction contextref="AsOf20190101_OtherEquityInterestMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:Equity" scale="3" sign="-" unitref="TWD">15,449,913</ix:nonfraction>)</pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20190101_EquityAttributableToOwnersOfParentMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:Equity" scale="3" unitref="TWD">1,676,817,665</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20190101_NoncontrollingInterestsMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:Equity" scale="3" unitref="TWD">678,731</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20190101_TotalEquityMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:Equity" scale="3" unitref="TWD">1,677,496,396</ix:nonfraction> </pre></td>
# </tr>
# <tr>
# <td>B1</td>
# <td>
# <span class="zh">提列法定盈餘公積</span>
# <span class="en">　　Legal reserve appropriated</span>
# </td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_OrdinaryShareMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:LegalReserveAppropriated" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_IssuedCapitalMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:LegalReserveAppropriated" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_CapitalReserveMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:LegalReserveAppropriated" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_StatutoryReserveMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:LegalReserveAppropriated" scale="3" unitref="TWD">35,113,088</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_SpecialReserveMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:LegalReserveAppropriated" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre>(<ix:nonfraction contextref="From20190101To20190630_UnappropriatedRetainedEarningsAccumulatedDeficitMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:LegalReserveAppropriated" scale="3" sign="-" unitref="TWD">35,113,088</ix:nonfraction>)</pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_RetainedEarningsMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:LegalReserveAppropriated" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_ReserveOfExchangeDifferencesOnTranslationMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:LegalReserveAppropriated" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_ReserveOfGainsAndLossesOnFinancialAssetsMeasuredAtFairValueThroughOtherComprehensiveIncomeMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:LegalReserveAppropriated" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_GainsLossesOnHedgingInstrumentsMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:LegalReserveAppropriated" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_Others-OtherEquityInterestMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:LegalReserveAppropriated" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_OtherEquityInterestMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:LegalReserveAppropriated" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_EquityAttributableToOwnersOfParentMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:LegalReserveAppropriated" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_NoncontrollingInterestsMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:LegalReserveAppropriated" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_TotalEquityMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:LegalReserveAppropriated" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# </tr>
# <tr>
# <td>B3</td>
# <td>
# <span class="zh">提列特別盈餘公積</span>
# <span class="en">　　Special reserve appropriated</span>
# </td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_OrdinaryShareMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:SpecialReserveAppropriated" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_IssuedCapitalMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:SpecialReserveAppropriated" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_CapitalReserveMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:SpecialReserveAppropriated" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_StatutoryReserveMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:SpecialReserveAppropriated" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre>(<ix:nonfraction contextref="From20190101To20190630_SpecialReserveMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:SpecialReserveAppropriated" scale="3" sign="-" unitref="TWD">16,183,397</ix:nonfraction>)</pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_UnappropriatedRetainedEarningsAccumulatedDeficitMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:SpecialReserveAppropriated" scale="3" unitref="TWD">16,183,397</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_RetainedEarningsMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:SpecialReserveAppropriated" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_ReserveOfExchangeDifferencesOnTranslationMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:SpecialReserveAppropriated" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_ReserveOfGainsAndLossesOnFinancialAssetsMeasuredAtFairValueThroughOtherComprehensiveIncomeMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:SpecialReserveAppropriated" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_GainsLossesOnHedgingInstrumentsMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:SpecialReserveAppropriated" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_Others-OtherEquityInterestMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:SpecialReserveAppropriated" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_OtherEquityInterestMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:SpecialReserveAppropriated" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_EquityAttributableToOwnersOfParentMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:SpecialReserveAppropriated" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_NoncontrollingInterestsMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:SpecialReserveAppropriated" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_TotalEquityMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:SpecialReserveAppropriated" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# </tr>
# <tr>
# <td>B5</td>
# <td>
# <span class="zh">普通股現金股利</span>
# <span class="en">　　Cash dividends of ordinary share</span>
# </td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_OrdinaryShareMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:CashDividendsOfOrdinaryShare" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_IssuedCapitalMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:CashDividendsOfOrdinaryShare" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_CapitalReserveMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:CashDividendsOfOrdinaryShare" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_StatutoryReserveMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:CashDividendsOfOrdinaryShare" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_SpecialReserveMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:CashDividendsOfOrdinaryShare" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre>(<ix:nonfraction contextref="From20190101To20190630_UnappropriatedRetainedEarningsAccumulatedDeficitMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:CashDividendsOfOrdinaryShare" scale="3" sign="-" unitref="TWD">259,303,805</ix:nonfraction>)</pre></td>
# <td class="amt"><pre>(<ix:nonfraction contextref="From20190101To20190630_RetainedEarningsMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:CashDividendsOfOrdinaryShare" scale="3" sign="-" unitref="TWD">259,303,805</ix:nonfraction>)</pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_ReserveOfExchangeDifferencesOnTranslationMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:CashDividendsOfOrdinaryShare" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_ReserveOfGainsAndLossesOnFinancialAssetsMeasuredAtFairValueThroughOtherComprehensiveIncomeMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:CashDividendsOfOrdinaryShare" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_GainsLossesOnHedgingInstrumentsMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:CashDividendsOfOrdinaryShare" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_Others-OtherEquityInterestMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:CashDividendsOfOrdinaryShare" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_OtherEquityInterestMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:CashDividendsOfOrdinaryShare" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre>(<ix:nonfraction contextref="From20190101To20190630_EquityAttributableToOwnersOfParentMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:CashDividendsOfOrdinaryShare" scale="3" sign="-" unitref="TWD">259,303,805</ix:nonfraction>)</pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_NoncontrollingInterestsMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:CashDividendsOfOrdinaryShare" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre>(<ix:nonfraction contextref="From20190101To20190630_TotalEquityMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:CashDividendsOfOrdinaryShare" scale="3" sign="-" unitref="TWD">259,303,805</ix:nonfraction>)</pre></td>
# </tr>
# <tr>
# <td>C7</td>
# <td>
# <span class="zh">採用權益法認列之關聯企業及合資之變動數</span>
# <span class="en">　　Changes in equity of associates and joint ventures accounted for using equity method</span>
# </td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_OrdinaryShareMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInEquityOfAssociatesAndJointVenturesAccountedForUsingEquityMethod" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_IssuedCapitalMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInEquityOfAssociatesAndJointVenturesAccountedForUsingEquityMethod" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_CapitalReserveMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInEquityOfAssociatesAndJointVenturesAccountedForUsingEquityMethod" scale="3" unitref="TWD">4,627</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_StatutoryReserveMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInEquityOfAssociatesAndJointVenturesAccountedForUsingEquityMethod" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_SpecialReserveMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInEquityOfAssociatesAndJointVenturesAccountedForUsingEquityMethod" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_UnappropriatedRetainedEarningsAccumulatedDeficitMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInEquityOfAssociatesAndJointVenturesAccountedForUsingEquityMethod" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_RetainedEarningsMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInEquityOfAssociatesAndJointVenturesAccountedForUsingEquityMethod" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_ReserveOfExchangeDifferencesOnTranslationMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInEquityOfAssociatesAndJointVenturesAccountedForUsingEquityMethod" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_ReserveOfGainsAndLossesOnFinancialAssetsMeasuredAtFairValueThroughOtherComprehensiveIncomeMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInEquityOfAssociatesAndJointVenturesAccountedForUsingEquityMethod" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_GainsLossesOnHedgingInstrumentsMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInEquityOfAssociatesAndJointVenturesAccountedForUsingEquityMethod" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_Others-OtherEquityInterestMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInEquityOfAssociatesAndJointVenturesAccountedForUsingEquityMethod" scale="3" unitref="TWD">1,843</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_OtherEquityInterestMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInEquityOfAssociatesAndJointVenturesAccountedForUsingEquityMethod" scale="3" unitref="TWD">1,843</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_EquityAttributableToOwnersOfParentMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInEquityOfAssociatesAndJointVenturesAccountedForUsingEquityMethod" scale="3" unitref="TWD">6,470</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_NoncontrollingInterestsMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInEquityOfAssociatesAndJointVenturesAccountedForUsingEquityMethod" scale="3" unitref="TWD">110</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_TotalEquityMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInEquityOfAssociatesAndJointVenturesAccountedForUsingEquityMethod" scale="3" unitref="TWD">6,580</ix:nonfraction> </pre></td>
# </tr>
# <tr>
# <td>D1</td>
# <td>
# <span class="zh">本期淨利（淨損）</span>
# <span class="en">　Profit (loss)</span>
# </td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_OrdinaryShareMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ProfitLoss" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_IssuedCapitalMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ProfitLoss" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_CapitalReserveMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ProfitLoss" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_StatutoryReserveMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ProfitLoss" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_SpecialReserveMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ProfitLoss" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_UnappropriatedRetainedEarningsAccumulatedDeficitMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ProfitLoss" scale="3" unitref="TWD">128,158,701</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_RetainedEarningsMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ProfitLoss" scale="3" unitref="TWD">128,158,701</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_ReserveOfExchangeDifferencesOnTranslationMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ProfitLoss" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_ReserveOfGainsAndLossesOnFinancialAssetsMeasuredAtFairValueThroughOtherComprehensiveIncomeMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ProfitLoss" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_GainsLossesOnHedgingInstrumentsMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ProfitLoss" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_Others-OtherEquityInterestMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ProfitLoss" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_OtherEquityInterestMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ProfitLoss" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_EquityAttributableToOwnersOfParentMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ProfitLoss" scale="3" unitref="TWD">128,158,701</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_NoncontrollingInterestsMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ProfitLoss" scale="3" unitref="TWD">4,460</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_TotalEquityMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ProfitLoss" scale="3" unitref="TWD">128,163,161</ix:nonfraction> </pre></td>
# </tr>
# <tr>
# <td>D3</td>
# <td>
# <span class="zh">本期其他綜合損益</span>
# <span class="en">　Other comprehensive income</span>
# </td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_OrdinaryShareMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:OtherComprehensiveIncome" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_IssuedCapitalMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:OtherComprehensiveIncome" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_CapitalReserveMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:OtherComprehensiveIncome" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_StatutoryReserveMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:OtherComprehensiveIncome" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_SpecialReserveMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:OtherComprehensiveIncome" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_UnappropriatedRetainedEarningsAccumulatedDeficitMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:OtherComprehensiveIncome" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_RetainedEarningsMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:OtherComprehensiveIncome" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_ReserveOfExchangeDifferencesOnTranslationMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:OtherComprehensiveIncome" scale="3" unitref="TWD">5,533,346</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_ReserveOfGainsAndLossesOnFinancialAssetsMeasuredAtFairValueThroughOtherComprehensiveIncomeMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:OtherComprehensiveIncome" scale="3" unitref="TWD">2,596,706</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_GainsLossesOnHedgingInstrumentsMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:OtherComprehensiveIncome" scale="3" unitref="TWD">11,901</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_Others-OtherEquityInterestMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:OtherComprehensiveIncome" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_OtherEquityInterestMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:OtherComprehensiveIncome" scale="3" unitref="TWD">8,141,953</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_EquityAttributableToOwnersOfParentMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:OtherComprehensiveIncome" scale="3" unitref="TWD">8,141,953</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_NoncontrollingInterestsMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:OtherComprehensiveIncome" scale="3" unitref="TWD">53</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_TotalEquityMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:OtherComprehensiveIncome" scale="3" unitref="TWD">8,142,006</ix:nonfraction> </pre></td>
# </tr>
# <tr>
# <td>D5</td>
# <td>
# <span class="zh">本期綜合損益總額</span>
# <span class="en">　Total comprehensive income</span>
# </td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_OrdinaryShareMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ComprehensiveIncome" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_IssuedCapitalMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ComprehensiveIncome" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_CapitalReserveMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ComprehensiveIncome" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_StatutoryReserveMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ComprehensiveIncome" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_SpecialReserveMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ComprehensiveIncome" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_UnappropriatedRetainedEarningsAccumulatedDeficitMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ComprehensiveIncome" scale="3" unitref="TWD">128,158,701</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_RetainedEarningsMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ComprehensiveIncome" scale="3" unitref="TWD">128,158,701</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_ReserveOfExchangeDifferencesOnTranslationMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ComprehensiveIncome" scale="3" unitref="TWD">5,533,346</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_ReserveOfGainsAndLossesOnFinancialAssetsMeasuredAtFairValueThroughOtherComprehensiveIncomeMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ComprehensiveIncome" scale="3" unitref="TWD">2,596,706</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_GainsLossesOnHedgingInstrumentsMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ComprehensiveIncome" scale="3" unitref="TWD">11,901</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_Others-OtherEquityInterestMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ComprehensiveIncome" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_OtherEquityInterestMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ComprehensiveIncome" scale="3" unitref="TWD">8,141,953</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_EquityAttributableToOwnersOfParentMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ComprehensiveIncome" scale="3" unitref="TWD">136,300,654</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_NoncontrollingInterestsMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ComprehensiveIncome" scale="3" unitref="TWD">4,513</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_TotalEquityMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ComprehensiveIncome" scale="3" unitref="TWD">136,305,167</ix:nonfraction> </pre></td>
# </tr>
# <tr>
# <td>M7</td>
# <td>
# <span class="zh">對子公司所有權權益變動</span>
# <span class="en">　Changes in ownership interests in subsidiaries</span>
# </td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_OrdinaryShareMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInOwnershipInterestsInSubsidiaries" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_IssuedCapitalMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInOwnershipInterestsInSubsidiaries" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_CapitalReserveMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInOwnershipInterestsInSubsidiaries" scale="3" unitref="TWD">370</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_StatutoryReserveMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInOwnershipInterestsInSubsidiaries" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_SpecialReserveMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInOwnershipInterestsInSubsidiaries" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_UnappropriatedRetainedEarningsAccumulatedDeficitMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInOwnershipInterestsInSubsidiaries" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_RetainedEarningsMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInOwnershipInterestsInSubsidiaries" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_ReserveOfExchangeDifferencesOnTranslationMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInOwnershipInterestsInSubsidiaries" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_ReserveOfGainsAndLossesOnFinancialAssetsMeasuredAtFairValueThroughOtherComprehensiveIncomeMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInOwnershipInterestsInSubsidiaries" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_GainsLossesOnHedgingInstrumentsMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInOwnershipInterestsInSubsidiaries" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_Others-OtherEquityInterestMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInOwnershipInterestsInSubsidiaries" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_OtherEquityInterestMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInOwnershipInterestsInSubsidiaries" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_EquityAttributableToOwnersOfParentMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInOwnershipInterestsInSubsidiaries" scale="3" unitref="TWD">370</ix:nonfraction> </pre></td>
# <td class="amt"><pre>(<ix:nonfraction contextref="From20190101To20190630_NoncontrollingInterestsMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInOwnershipInterestsInSubsidiaries" scale="3" sign="-" unitref="TWD">370</ix:nonfraction>)</pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_TotalEquityMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInOwnershipInterestsInSubsidiaries" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# </tr>
# <tr>
# <td>O1</td>
# <td>
# <span class="zh">非控制權益增減</span>
# <span class="en">　Changes in non-controlling interests</span>
# </td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_OrdinaryShareMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInNoncontrollingInterests" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_IssuedCapitalMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInNoncontrollingInterests" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_CapitalReserveMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInNoncontrollingInterests" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_StatutoryReserveMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInNoncontrollingInterests" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_SpecialReserveMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInNoncontrollingInterests" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_UnappropriatedRetainedEarningsAccumulatedDeficitMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInNoncontrollingInterests" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_RetainedEarningsMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInNoncontrollingInterests" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_ReserveOfExchangeDifferencesOnTranslationMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInNoncontrollingInterests" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_ReserveOfGainsAndLossesOnFinancialAssetsMeasuredAtFairValueThroughOtherComprehensiveIncomeMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInNoncontrollingInterests" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_GainsLossesOnHedgingInstrumentsMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInNoncontrollingInterests" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_Others-OtherEquityInterestMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInNoncontrollingInterests" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_OtherEquityInterestMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInNoncontrollingInterests" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_EquityAttributableToOwnersOfParentMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInNoncontrollingInterests" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre>(<ix:nonfraction contextref="From20190101To20190630_NoncontrollingInterestsMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInNoncontrollingInterests" scale="3" sign="-" unitref="TWD">76,036</ix:nonfraction>)</pre></td>
# <td class="amt"><pre>(<ix:nonfraction contextref="From20190101To20190630_TotalEquityMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInNoncontrollingInterests" scale="3" sign="-" unitref="TWD">76,036</ix:nonfraction>)</pre></td>
# </tr>
# <tr>
# <td>Q1</td>
# <td>
# <span class="zh">處分透過其他綜合損益按公允價值衡量之權益工具</span>
# <span class="en">　Disposal of investments in equity instruments designated at fair value through other comprehensive income</span>
# </td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_OrdinaryShareMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:DisposalOfInvestmentsInEquityInstrumentsDesignatedAtFairValueThroughOtherComprehensiveIncome" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_IssuedCapitalMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:DisposalOfInvestmentsInEquityInstrumentsDesignatedAtFairValueThroughOtherComprehensiveIncome" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_CapitalReserveMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:DisposalOfInvestmentsInEquityInstrumentsDesignatedAtFairValueThroughOtherComprehensiveIncome" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_StatutoryReserveMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:DisposalOfInvestmentsInEquityInstrumentsDesignatedAtFairValueThroughOtherComprehensiveIncome" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_SpecialReserveMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:DisposalOfInvestmentsInEquityInstrumentsDesignatedAtFairValueThroughOtherComprehensiveIncome" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_UnappropriatedRetainedEarningsAccumulatedDeficitMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:DisposalOfInvestmentsInEquityInstrumentsDesignatedAtFairValueThroughOtherComprehensiveIncome" scale="3" unitref="TWD">73,048</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_RetainedEarningsMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:DisposalOfInvestmentsInEquityInstrumentsDesignatedAtFairValueThroughOtherComprehensiveIncome" scale="3" unitref="TWD">73,048</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_ReserveOfExchangeDifferencesOnTranslationMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:DisposalOfInvestmentsInEquityInstrumentsDesignatedAtFairValueThroughOtherComprehensiveIncome" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre>(<ix:nonfraction contextref="From20190101To20190630_ReserveOfGainsAndLossesOnFinancialAssetsMeasuredAtFairValueThroughOtherComprehensiveIncomeMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:DisposalOfInvestmentsInEquityInstrumentsDesignatedAtFairValueThroughOtherComprehensiveIncome" scale="3" sign="-" unitref="TWD">73,048</ix:nonfraction>)</pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_GainsLossesOnHedgingInstrumentsMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:DisposalOfInvestmentsInEquityInstrumentsDesignatedAtFairValueThroughOtherComprehensiveIncome" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_Others-OtherEquityInterestMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:DisposalOfInvestmentsInEquityInstrumentsDesignatedAtFairValueThroughOtherComprehensiveIncome" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre>(<ix:nonfraction contextref="From20190101To20190630_OtherEquityInterestMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:DisposalOfInvestmentsInEquityInstrumentsDesignatedAtFairValueThroughOtherComprehensiveIncome" scale="3" sign="-" unitref="TWD">73,048</ix:nonfraction>)</pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_EquityAttributableToOwnersOfParentMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:DisposalOfInvestmentsInEquityInstrumentsDesignatedAtFairValueThroughOtherComprehensiveIncome" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_NoncontrollingInterestsMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:DisposalOfInvestmentsInEquityInstrumentsDesignatedAtFairValueThroughOtherComprehensiveIncome" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_TotalEquityMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:DisposalOfInvestmentsInEquityInstrumentsDesignatedAtFairValueThroughOtherComprehensiveIncome" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# </tr>
# <tr>
# <td>T1</td>
# <td>
# <span class="zh">其他</span>
# <span class="en">　Others</span>
# </td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_OrdinaryShareMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:Others-IncreaseDecreaseInEquity" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_IssuedCapitalMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:Others-IncreaseDecreaseInEquity" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_CapitalReserveMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:Others-IncreaseDecreaseInEquity" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_StatutoryReserveMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:Others-IncreaseDecreaseInEquity" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_SpecialReserveMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:Others-IncreaseDecreaseInEquity" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_UnappropriatedRetainedEarningsAccumulatedDeficitMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:Others-IncreaseDecreaseInEquity" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_RetainedEarningsMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:Others-IncreaseDecreaseInEquity" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_ReserveOfExchangeDifferencesOnTranslationMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:Others-IncreaseDecreaseInEquity" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_ReserveOfGainsAndLossesOnFinancialAssetsMeasuredAtFairValueThroughOtherComprehensiveIncomeMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:Others-IncreaseDecreaseInEquity" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre>(<ix:nonfraction contextref="From20190101To20190630_GainsLossesOnHedgingInstrumentsMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:Others-IncreaseDecreaseInEquity" scale="3" sign="-" unitref="TWD">6,775</ix:nonfraction>)</pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_Others-OtherEquityInterestMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:Others-IncreaseDecreaseInEquity" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre>(<ix:nonfraction contextref="From20190101To20190630_OtherEquityInterestMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:Others-IncreaseDecreaseInEquity" scale="3" sign="-" unitref="TWD">6,775</ix:nonfraction>)</pre></td>
# <td class="amt"><pre>(<ix:nonfraction contextref="From20190101To20190630_EquityAttributableToOwnersOfParentMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:Others-IncreaseDecreaseInEquity" scale="3" sign="-" unitref="TWD">6,775</ix:nonfraction>)</pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_NoncontrollingInterestsMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:Others-IncreaseDecreaseInEquity" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre>(<ix:nonfraction contextref="From20190101To20190630_TotalEquityMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:Others-IncreaseDecreaseInEquity" scale="3" sign="-" unitref="TWD">6,775</ix:nonfraction>)</pre></td>
# </tr>
# <tr>
# <td>Y1</td>
# <td>
# <span class="zh">權益增加(減少)總額</span>
# <span class="en">　Total increase (decrease) in equity</span>
# </td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_OrdinaryShareMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ChangesInEquity" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_IssuedCapitalMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ChangesInEquity" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_CapitalReserveMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ChangesInEquity" scale="3" unitref="TWD">4,997</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_StatutoryReserveMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ChangesInEquity" scale="3" unitref="TWD">35,113,088</ix:nonfraction> </pre></td>
# <td class="amt"><pre>(<ix:nonfraction contextref="From20190101To20190630_SpecialReserveMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ChangesInEquity" scale="3" sign="-" unitref="TWD">16,183,397</ix:nonfraction>)</pre></td>
# <td class="amt"><pre>(<ix:nonfraction contextref="From20190101To20190630_UnappropriatedRetainedEarningsAccumulatedDeficitMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ChangesInEquity" scale="3" sign="-" unitref="TWD">150,001,747</ix:nonfraction>)</pre></td>
# <td class="amt"><pre>(<ix:nonfraction contextref="From20190101To20190630_RetainedEarningsMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ChangesInEquity" scale="3" sign="-" unitref="TWD">131,072,056</ix:nonfraction>)</pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_ReserveOfExchangeDifferencesOnTranslationMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ChangesInEquity" scale="3" unitref="TWD">5,533,346</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_ReserveOfGainsAndLossesOnFinancialAssetsMeasuredAtFairValueThroughOtherComprehensiveIncomeMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ChangesInEquity" scale="3" unitref="TWD">2,523,658</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_GainsLossesOnHedgingInstrumentsMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ChangesInEquity" scale="3" unitref="TWD">5,126</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_Others-OtherEquityInterestMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ChangesInEquity" scale="3" unitref="TWD">1,843</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_OtherEquityInterestMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ChangesInEquity" scale="3" unitref="TWD">8,063,973</ix:nonfraction> </pre></td>
# <td class="amt"><pre>(<ix:nonfraction contextref="From20190101To20190630_EquityAttributableToOwnersOfParentMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ChangesInEquity" scale="3" sign="-" unitref="TWD">123,003,086</ix:nonfraction>)</pre></td>
# <td class="amt"><pre>(<ix:nonfraction contextref="From20190101To20190630_NoncontrollingInterestsMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ChangesInEquity" scale="3" sign="-" unitref="TWD">71,783</ix:nonfraction>)</pre></td>
# <td class="amt"><pre>(<ix:nonfraction contextref="From20190101To20190630_TotalEquityMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ChangesInEquity" scale="3" sign="-" unitref="TWD">123,074,869</ix:nonfraction>)</pre></td>
# </tr>
# <tr>
# <td>Z1</td>
# <td>
# <span class="zh">期末餘額</span>
# <span class="en">　Equity at end of period</span>
# </td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20190630_OrdinaryShareMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:Equity" scale="3" unitref="TWD">259,303,805</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20190630_IssuedCapitalMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:Equity" scale="3" unitref="TWD">259,303,805</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20190630_CapitalReserveMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:Equity" scale="3" unitref="TWD">56,320,929</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20190630_StatutoryReserveMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:Equity" scale="3" unitref="TWD">311,146,899</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20190630_SpecialReserveMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:Equity" scale="3" unitref="TWD">10,724,130</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20190630_UnappropriatedRetainedEarningsAccumulatedDeficitMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:Equity" scale="3" unitref="TWD">923,704,756</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20190630_RetainedEarningsMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:Equity" scale="3" unitref="TWD">1,245,575,785</ix:nonfraction> </pre></td>
# <td class="amt"><pre>(<ix:nonfraction contextref="AsOf20190630_ReserveOfExchangeDifferencesOnTranslationMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:Equity" scale="3" sign="-" unitref="TWD">6,509,001</ix:nonfraction>)</pre></td>
# <td class="amt"><pre>(<ix:nonfraction contextref="AsOf20190630_ReserveOfGainsAndLossesOnFinancialAssetsMeasuredAtFairValueThroughOtherComprehensiveIncomeMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:Equity" scale="3" sign="-" unitref="TWD">905,666</ix:nonfraction>)</pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20190630_GainsLossesOnHedgingInstrumentsMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:Equity" scale="3" unitref="TWD">28,727</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20190630_Others-OtherEquityInterestMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:Equity" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre>(<ix:nonfraction contextref="AsOf20190630_OtherEquityInterestMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:Equity" scale="3" sign="-" unitref="TWD">7,385,940</ix:nonfraction>)</pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20190630_EquityAttributableToOwnersOfParentMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:Equity" scale="3" unitref="TWD">1,553,814,579</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20190630_NoncontrollingInterestsMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:Equity" scale="3" unitref="TWD">606,948</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20190630_TotalEquityMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:Equity" scale="3" unitref="TWD">1,554,421,527</ix:nonfraction> </pre></td>
# </tr>
# </table>

# %% [markdown]
# # Find A1, B1....Index

# %%
td=Etable.select('td')
#print(td)

CI=[]
for _td in td:
    if re.findall('^[A-Z][0-9]', _td.text.strip()) !=[]:
        CI.append(re.findall('^[A-Z][0-9]', _td.text.strip()))
        #print(code_index[0])

# %%
import re
import pandas as pd
import numpy as np

th=Etable.select('th')
cht = Etable.select('span.zh')
en = Etable.select('span.en')
amt = Etable.select('td.amt')

#code4=[]
code4={}

j=1
for _th in th:
    if re.findall('^3.+', _th.text.strip()) !=[]:
        #print(_th.text.strip())
        #print(cht[j].text.strip())
        #print(en[j].text.strip())
        #code4.append({'code':_th.text.strip(),'cht': cht[j].text.strip(), 'en':en[j].text.strip()})
        code4[_th.text.strip()]={'cName':{'cht': cht[j].text.strip(),'en':en[j].text.strip()}}
        j+=1
print(code4)
print(code4.keys())

#index=[]
index2={}
for _cht, _en, _CI in zip(cht[j:], en[j:], CI):
    #index.append({'code_index':_CI[0],'cht_index':_cht.text.strip(), 'en_index': _en.text.strip()})
    index2[_CI[0]]={'iName':{'cht': _cht.text.strip(),'en': _en.text.strip()}}
    #print(code_index)
    #print(cht_index)
    #print(en_index)               
#print(index2)
#print(index2.keys())

k= len(code4)

#print(k)


#for _amt in amt:
#    print(_amt.text)

amt_row= [[] for x in range(k-1)]
#print(amt_row)
j=0
for i, _amt in enumerate(amt):
    #print(i, _amt.text)
    if i==0 or i % k!= 0:
        amt_row[j].append(_amt.text.strip().replace(',','').replace('(','-').replace(')',''))
        #print(amt_row[j])
    else:
        j+=1
        amt_row[j].append(_amt.text.strip().replace(',','').replace('(','-').replace(')',''))
#print(amt_row)

df=pd.DataFrame(columns=code4.keys())

df=pd.DataFrame(np.array(amt_row),
                   columns=code4.keys())
df['items']=index2.keys()
df.set_index('items', inplace=True)
df
# Out:
# {'3110': {'cName': {'cht': '普通股股本', 'en': 'Ordinary share'}}, '3100': {'cName': {'cht': '股本合計', 'en': 'Total share capital'}}, '3200': {'cName': {'cht': '資本公積', 'en': 'Capital surplus'}}, '3310': {'cName': {'cht': '法定盈餘公積', 'en': 'Legal reserve'}}, '3320': {'cName': {'cht': '特別盈餘公積', 'en': 'Special reserve'}}, '3350': {'cName': {'cht': '未分配盈餘（或待彌補虧損）', 'en': 'Unappropriated retained earnings (accumulated deficit)'}}, '3300': {'cName': {'cht': '保留盈餘合計', 'en': 'Total retained earnings'}}, '3410': {'cName': {'cht': '國外營運機構財務報表換算之兌換差額', 'en': 'Exchange differences on translation of foreign financial statements'}}, '3420': {'cName': {'cht': '透過其他綜合損益按公允價值衡量之金融資產未實現評價(損)益', 'en': 'Unrealised gains (losses) on financial assets measured at fair value through other comprehensive income'}}, '3450': {'cName': {'cht': '避險工具之利益（損失）', 'en': 'Gains (losses) on hedging instruments'}}, '3490': {'cName': {'cht': '其他', 'en': 'Others'}}, '3400': {'cName': {'cht': '其他權益項目合計', 'en': 'Total other equity interest'}}, '31XX': {'cName': {'cht': '歸屬於母公司業主之權益總計', 'en': 'Total equity attributable to owners of parent'}}, '36XX': {'cName': {'cht': '非控制權益', 'en': 'Non-controlling interests'}}, '3XXX': {'cName': {'cht': '權益總額', 'en': 'Total equity'}}}
# dict_keys(['3110', '3100', '3200', '3310', '3320', '3350', '3300', '3410', '3420', '3450', '3490', '3400', '31XX', '36XX', '3XXX'])
#             3110       3100      3200       3310       3320        3350  \
# items
# A1     259303805  259303805  56315932  276033811   26907527  1073706503
# B1             0          0         0   35113088          0   -35113088
# B3             0          0         0          0  -16183397    16183397
# B5             0          0         0          0          0  -259303805
# C7             0          0      4627          0          0           0
# D1             0          0         0          0          0   128158701
# D3             0          0         0          0          0           0
# D5             0          0         0          0          0   128158701
# M7             0          0       370          0          0           0
# O1             0          0         0          0          0           0
# Q1             0          0         0          0          0       73048
# T1             0          0         0          0          0           0
# Y1             0          0      4997   35113088  -16183397  -150001747
# Z1     259303805  259303805  56320929  311146899   10724130   923704756
#
#              3300       3410      3420   3450   3490       3400        31XX  \
# items
# A1     1376647841  -12042347  -3429324  23601  -1843  -15449913  1676817665
# B1              0          0         0      0      0          0           0
# B3              0          0         0      0      0          0           0
# B5     -259303805          0         0      0      0          0  -259303805
# C7              0          0         0      0   1843       1843        6470
# D1      128158701          0         0      0      0          0   128158701
# D3              0    5533346   2596706  11901      0    8141953     8141953
# D5      128158701    5533346   2596706  11901      0    8141953   136300654
# M7              0          0         0      0      0          0         370
# O1              0          0         0      0      0          0           0
# Q1          73048          0    -73048      0      0     -73048           0
# T1              0          0         0  -6775      0      -6775       -6775
# Y1     -131072056    5533346   2523658   5126   1843    8063973  -123003086
# Z1     1245575785   -6509001   -905666  28727      0   -7385940  1553814579
#
#          36XX        3XXX
# items
# A1     678731  1677496396
# B1          0           0
# B3          0           0
# B5          0  -259303805
# C7        110        6580
# D1       4460   128163161
# D3         53     8142006
# D5       4513   136305167
# M7       -370           0
# O1     -76036      -76036
# Q1          0           0
# T1          0       -6775
# Y1     -71783  -123074869
# Z1     606948  1554421527
