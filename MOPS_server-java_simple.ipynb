# %%
import requests
from requests.adapters import HTTPAdapter
from bs4 import BeautifulSoup as bs4

header= {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.106 Safari/537.36'}
url='https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=2330&SYEAR=2019&SSEASON=2&REPORT_ID=C'


web_ss = requests.session()
ss_adapter = HTTPAdapter(max_retries=3)
web_ss.mount("https://", adapter=ss_adapter)
res = web_ss.get(url=url, headers=header)
res.encoding = 'big5'
if res.status_code == 200:
    #soup = bs4(res.text, "lxml")
    soup = bs4(res.text, "html.parser")
    tables = soup.select('table')
print(tables)
# Out:
# [<table style="width:90%">
# <tr><th colspan="5"><span class="zh">資產負債表</span><span class="en">Balance Sheet</span></th></tr>
# <tr>
# <th><span class="zh">代號</span><span class="en">Code</span></th>
# <th><span class="zh">會計項目</span><span class="en">Accounting Title</span></th>
# <th><span class="zh">2019年6月30日</span><span class="en">2019/6/30</span></th>
# <th><span class="zh">2018年12月31日</span><span class="en">2018/12/31</span></th>
# <th><span class="zh">2018年6月30日</span><span class="en">2018/6/30</span></th>
# </tr>
# <tr>
# <td style="text-align:center"></td>
# <td><span class="zh">資產</span><span class="en">Assets</span></td>
# <td class="amt"></td>
# <td class="amt"></td>
# <td class="amt"></td>
# </tr>
# <tr>
# <td style="text-align:center"></td>
# <td><span class="zh">　流動資產</span><span class="en">　Current assets</span></td>
# <td class="amt"></td>
# <td class="amt"></td>
# <td class="amt"></td>
# </tr>
# <tr>
# <td style="text-align:center">1100</td>
# <td><span class="zh">　　現金及約當現金</span><span class="en">　　Cash and cash equivalents</span></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20190630" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:CashAndCashEquivalents" scale="3" unitref="TWD">649,697,262</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20181231" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:CashAndCashEquivalents" scale="3" unitref="TWD">577,814,601</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20180630" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:CashAndCashEquivalents" scale="3" unitref="TWD">632,229,880</ix:nonfraction> </pre></td>
# </tr>
# <tr>
# <td style="text-align:center">1110</td>
# <td><span class="zh">　　透過損益按公允價值衡量之金融資產－流動</span><span class="en">　　Current financial assets at fair value through profit or loss</span></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20190630" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:CurrentFinancialAssetsAtFairValueThroughProfitOrLoss" scale="3" unitref="TWD">1,322,756</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20181231" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:CurrentFinancialAssetsAtFairValueThroughProfitOrLoss" scale="3" unitref="TWD">3,504,590</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20180630" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:CurrentFinancialAssetsAtFairValueThroughProfitOrLoss" scale="3" unitref="TWD">1,205,036</ix:nonfraction> </pre></td>
# </tr>
# <tr>
# <td style="text-align:center">1120</td>
# <td><span class="zh">　　透過其他綜合損益按公允價值衡量之金融資產－流動</span><span class="en">　　Current financial assets at fair value through other comprehensive income</span></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20190630" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:CurrentFinancialAssetsAtFairValueThroughOtherComprehensiveIncome" scale="3" unitref="TWD">113,594,232</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20181231" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:CurrentFinancialAssetsAtFairValueThroughOtherComprehensiveIncome" scale="3" unitref="TWD">99,561,740</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20180630" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:CurrentFinancialAssetsAtFairValueThroughOtherComprehensiveIncome" scale="3" unitref="TWD">102,027,608</ix:nonfraction> </pre></td>
# </tr>
# <tr>
# <td style="text-align:center">1136</td>
# <td><span class="zh">　　按攤銷後成本衡量之金融資產－流動</span><span class="en">　　Current financial assets at amortised cost</span></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20190630" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:CurrentFinancialAssetsAtAmortisedCost" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20181231" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:CurrentFinancialAssetsAtAmortisedCost" scale="3" unitref="TWD">14,277,615</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20180630" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:CurrentFinancialAssetsAtAmortisedCost" scale="3" unitref="TWD">13,427,398</ix:nonfraction> </pre></td>
# </tr>
# <tr>
# <td style="text-align:center">1139</td>
# <td><span class="zh">　　避險之金融資產－流動</span><span class="en">　　Current financial assets for hedging</span></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20190630" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:HedgingInstrumentAssets" scale="3" unitref="TWD">576</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20181231" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:HedgingInstrumentAssets" scale="3" unitref="TWD">23,497</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20180630" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:HedgingInstrumentAssets" scale="3" unitref="TWD">31,692</ix:nonfraction> </pre></td>
# </tr>
# <tr>
# <td style="text-align:center">1170</td>
# <td><span class="zh">　　應收帳款淨額</span><span class="en">　　Accounts receivable, net</span></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20190630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-bsci-ci:AccountsReceivableNet" scale="3" unitref="TWD">115,725,802</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20181231" decimals="-3" format="ixt:numdotdecimal" name="tifrs-bsci-ci:AccountsReceivableNet" scale="3" unitref="TWD">128,613,391</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20180630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-bsci-ci:AccountsReceivableNet" scale="3" unitref="TWD">87,096,847</ix:nonfraction> </pre></td>
# </tr>
# <tr>
# <td style="text-align:center">1180</td>
# <td><span class="zh">　　應收帳款－關係人淨額</span><span class="en">　　Accounts receivable due from related parties, net</span></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20190630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-bsci-ci:AccountsReceivableDuefromRelatedPartiesNet" scale="3" unitref="TWD">404,906</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20181231" decimals="-3" format="ixt:numdotdecimal" name="tifrs-bsci-ci:AccountsReceivableDuefromRelatedPartiesNet" scale="3" unitref="TWD">584,412</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20180630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-bsci-ci:AccountsReceivableDuefromRelatedPartiesNet" scale="3" unitref="TWD">1,099,472</ix:nonfraction> </pre></td>
# </tr>
# <tr>
# <td style="text-align:center">1210</td>
# <td><span class="zh">　　其他應收款－關係人</span><span class="en">　　Other receivables due from related parties</span></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20190630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-bsci-ci:OtherReceivablesDueFromRelatedParties" scale="3" unitref="TWD">1,541,754</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20181231" decimals="-3" format="ixt:numdotdecimal" name="tifrs-bsci-ci:OtherReceivablesDueFromRelatedParties" scale="3" unitref="TWD">65,028</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20180630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-bsci-ci:OtherReceivablesDueFromRelatedParties" scale="3" unitref="TWD">3,185,522</ix:nonfraction> </pre></td>
# </tr>
# <tr>
# <td style="text-align:center">130X</td>
# <td><span class="zh">　　存貨</span><span class="en">　　Current inventories</span></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20190630" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:Inventories" scale="3" unitref="TWD">108,231,879</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20181231" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:Inventories" scale="3" unitref="TWD">103,230,976</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20180630" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:Inventories" scale="3" unitref="TWD">99,032,077</ix:nonfraction> </pre></td>
# </tr>
# <tr>
# <td style="text-align:center">1470</td>
# <td><span class="zh">　　其他流動資產</span><span class="en">　　Other current assets</span></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20190630" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:OtherCurrentAssets" scale="3" unitref="TWD">19,660,171</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20181231" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:OtherCurrentAssets" scale="3" unitref="TWD">24,003,871</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20180630" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:OtherCurrentAssets" scale="3" unitref="TWD">19,707,147</ix:nonfraction> </pre></td>
# </tr>
# <tr>
# <td style="text-align:center">1476</td>
# <td><span class="zh">　　　其他金融資產－流動</span><span class="en">　　　Other current financial assets</span></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20190630" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:OtherCurrentFinancialAssets" scale="3" unitref="TWD">14,934,531</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20181231" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:OtherCurrentFinancialAssets" scale="3" unitref="TWD">18,597,448</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20180630" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:OtherCurrentFinancialAssets" scale="3" unitref="TWD">13,393,142</ix:nonfraction> </pre></td>
# </tr>
# <tr>
# <td style="text-align:center">1479</td>
# <td><span class="zh">　　　其他流動資產－其他</span><span class="en">　　　Other current assets, others</span></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20190630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-bsci-ci:OtherCurrentAssetsOthers" scale="3" unitref="TWD">4,725,640</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20181231" decimals="-3" format="ixt:numdotdecimal" name="tifrs-bsci-ci:OtherCurrentAssetsOthers" scale="3" unitref="TWD">5,406,423</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20180630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-bsci-ci:OtherCurrentAssetsOthers" scale="3" unitref="TWD">6,314,005</ix:nonfraction> </pre></td>
# </tr>
# <tr>
# <td style="text-align:center">11XX</td>
# <td><span class="zh">　　流動資產合計</span><span class="en">　　Total current assets</span></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20190630" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:CurrentAssets" scale="3" unitref="TWD">1,010,179,338</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20181231" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:CurrentAssets" scale="3" unitref="TWD">951,679,721</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20180630" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:CurrentAssets" scale="3" unitref="TWD">959,042,679</ix:nonfraction> </pre></td>
# </tr>
# <tr>
# <td style="text-align:center"></td>
# <td><span class="zh">　非流動資產</span><span class="en">　Non-current assets</span></td>
# <td class="amt"></td>
# <td class="amt"></td>
# <td class="amt"></td>
# </tr>
# <tr>
# <td style="text-align:center">1517</td>
# <td><span class="zh">　　透過其他綜合損益按公允價值衡量之金融資產－非流動</span><span class="en">　　Non-current financial assets at fair value through other comprehensive income</span></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20190630" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:NoncurrentFinancialAssetsAtFairValueThroughOtherComprehensiveIncome" scale="3" unitref="TWD">4,040,800</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20181231" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:NoncurrentFinancialAssetsAtFairValueThroughOtherComprehensiveIncome" scale="3" unitref="TWD">3,910,681</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20180630" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:NoncurrentFinancialAssetsAtFairValueThroughOtherComprehensiveIncome" scale="3" unitref="TWD">5,694,784</ix:nonfraction> </pre></td>
# </tr>
# <tr>
# <td style="text-align:center">1535</td>
# <td><span class="zh">　　按攤銷後成本衡量之金融資產－非流動</span><span class="en">　　Non-current financial assets at amortised cost</span></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20190630" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:NoncurrentFinancialAssetsAtAmortisedCost" scale="3" unitref="TWD">7,921,781</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20181231" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:NoncurrentFinancialAssetsAtAmortisedCost" scale="3" unitref="TWD">7,528,277</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20180630" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:NoncurrentFinancialAssetsAtAmortisedCost" scale="3" unitref="TWD">7,476,874</ix:nonfraction> </pre></td>
# </tr>
# <tr>
# <td style="text-align:center">1550</td>
# <td><span class="zh">　　採用權益法之投資</span><span class="en">　　Investments accounted for using equity method</span></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20190630" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:InvestmentAccountedForUsingEquityMethod" scale="3" unitref="TWD">17,352,733</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20181231" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:InvestmentAccountedForUsingEquityMethod" scale="3" unitref="TWD">17,865,838</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20180630" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:InvestmentAccountedForUsingEquityMethod" scale="3" unitref="TWD">15,663,648</ix:nonfraction> </pre></td>
# </tr>
# <tr>
# <td style="text-align:center">1600</td>
# <td><span class="zh">　　不動產、廠房及設備</span><span class="en">　　Property, plant and equipment</span></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20190630" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:PropertyPlantAndEquipment" scale="3" unitref="TWD">1,142,871,184</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20181231" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:PropertyPlantAndEquipment" scale="3" unitref="TWD">1,072,050,279</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20180630" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:PropertyPlantAndEquipment" scale="3" unitref="TWD">1,034,268,062</ix:nonfraction> </pre></td>
# </tr>
# <tr>
# <td style="text-align:center">1755</td>
# <td><span class="zh">　　使用權資產</span><span class="en">　　Right-of-use assets</span></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20190630" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:RightofuseAssets" scale="3" unitref="TWD">18,042,308</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20181231" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:RightofuseAssets" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20180630" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:RightofuseAssets" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# </tr>
# <tr>
# <td style="text-align:center">1780</td>
# <td><span class="zh">　　無形資產</span><span class="en">　　Intangible assets</span></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20190630" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:IntangibleAssetsAndGoodwill" scale="3" unitref="TWD">17,500,830</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20181231" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:IntangibleAssetsAndGoodwill" scale="3" unitref="TWD">17,002,137</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20180630" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:IntangibleAssetsAndGoodwill" scale="3" unitref="TWD">13,792,211</ix:nonfraction> </pre></td>
# </tr>
# <tr>
# <td style="text-align:center">1840</td>
# <td><span class="zh">　　遞延所得稅資產</span><span class="en">　　Deferred tax assets</span></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20190630" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:DeferredTaxAssets" scale="3" unitref="TWD">17,123,994</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20181231" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:DeferredTaxAssets" scale="3" unitref="TWD">16,806,387</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20180630" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:DeferredTaxAssets" scale="3" unitref="TWD">13,632,059</ix:nonfraction> </pre></td>
# </tr>
# <tr>
# <td style="text-align:center">1900</td>
# <td><span class="zh">　　其他非流動資產</span><span class="en">　　Other non-current assets</span></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20190630" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:OtherNoncurrentAssets" scale="3" unitref="TWD">4,310,703</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20181231" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:OtherNoncurrentAssets" scale="3" unitref="TWD">3,284,718</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20180630" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:OtherNoncurrentAssets" scale="3" unitref="TWD">3,842,637</ix:nonfraction> </pre></td>
# </tr>
# <tr>
# <td style="text-align:center">1920</td>
# <td><span class="zh">　　　存出保證金</span><span class="en">　　　Guarantee deposits paid</span></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20190630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-bsci-ci:GuaranteeDepositsPaid" scale="3" unitref="TWD">2,570,491</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20181231" decimals="-3" format="ixt:numdotdecimal" name="tifrs-bsci-ci:GuaranteeDepositsPaid" scale="3" unitref="TWD">1,700,071</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20180630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-bsci-ci:GuaranteeDepositsPaid" scale="3" unitref="TWD">2,110,444</ix:nonfraction> </pre></td>
# </tr>
# <tr>
# <td style="text-align:center">1990</td>
# <td><span class="zh">　　　其他非流動資產－其他</span><span class="en">　　　Other non-current assets, others</span></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20190630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-bsci-ci:OtherNoncurrentAssetsOthers" scale="3" unitref="TWD">1,740,212</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20181231" decimals="-3" format="ixt:numdotdecimal" name="tifrs-bsci-ci:OtherNoncurrentAssetsOthers" scale="3" unitref="TWD">1,584,647</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20180630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-bsci-ci:OtherNoncurrentAssetsOthers" scale="3" unitref="TWD">1,732,193</ix:nonfraction> </pre></td>
# </tr>
# <tr>
# <td style="text-align:center">15XX</td>
# <td><span class="zh">　　非流動資產合計</span><span class="en">　　Total non-current assets</span></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20190630" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:NoncurrentAssets" scale="3" unitref="TWD">1,229,164,333</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20181231" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:NoncurrentAssets" scale="3" unitref="TWD">1,138,448,317</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20180630" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:NoncurrentAssets" scale="3" unitref="TWD">1,094,370,275</ix:nonfraction> </pre></td>
# </tr>
# <tr>
# <td style="text-align:center">1XXX</td>
# <td><span class="zh">　資產總計</span><span class="en">　Total assets</span></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20190630" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:Assets" scale="3" unitref="TWD">2,239,343,671</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20181231" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:Assets" scale="3" unitref="TWD">2,090,128,038</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20180630" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:Assets" scale="3" unitref="TWD">2,053,412,954</ix:nonfraction> </pre></td>
# </tr>
# <tr>
# <td style="text-align:center"></td>
# <td><span class="zh">負債及權益</span><span class="en">Liabilities and equity</span></td>
# <td class="amt"></td>
# <td class="amt"></td>
# <td class="amt"></td>
# </tr>
# <tr>
# <td style="text-align:center"></td>
# <td><span class="zh">　負債</span><span class="en">　Liabilities</span></td>
# <td class="amt"></td>
# <td class="amt"></td>
# <td class="amt"></td>
# </tr>
# <tr>
# <td style="text-align:center"></td>
# <td><span class="zh">　　流動負債</span><span class="en">　　Current liabilities</span></td>
# <td class="amt"></td>
# <td class="amt"></td>
# <td class="amt"></td>
# </tr>
# <tr>
# <td style="text-align:center">2100</td>
# <td><span class="zh">　　　短期借款</span><span class="en">　　　Current borrowings</span></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20190630" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ShorttermBorrowings" scale="3" unitref="TWD">78,261,120</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20181231" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ShorttermBorrowings" scale="3" unitref="TWD">88,754,640</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20180630" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ShorttermBorrowings" scale="3" unitref="TWD">30,835,300</ix:nonfraction> </pre></td>
# </tr>
# <tr>
# <td style="text-align:center">2120</td>
# <td><span class="zh">　　　透過損益按公允價值衡量之金融負債－流動</span><span class="en">　　　Current financial liabilities at fair value through profit or loss</span></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20190630" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:CurrentFinancialLiabilitiesAtFairValueThroughProfitOrLoss" scale="3" unitref="TWD">30,767</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20181231" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:CurrentFinancialLiabilitiesAtFairValueThroughProfitOrLoss" scale="3" unitref="TWD">40,825</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20180630" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:CurrentFinancialLiabilitiesAtFairValueThroughProfitOrLoss" scale="3" unitref="TWD">1,057,719</ix:nonfraction> </pre></td>
# </tr>
# <tr>
# <td style="text-align:center">2126</td>
# <td><span class="zh">　　　避險之金融負債－流動</span><span class="en">　　　Current financial liabilities for hedging</span></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20190630" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:HedgingInstrumentLiabilities" scale="3" unitref="TWD">34,542</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20181231" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:HedgingInstrumentLiabilities" scale="3" unitref="TWD">155,832</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20180630" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:HedgingInstrumentLiabilities" scale="3" unitref="TWD">30,718</ix:nonfraction> </pre></td>
# </tr>
# <tr>
# <td style="text-align:center">2170</td>
# <td><span class="zh">　　　應付帳款</span><span class="en">　　　Accounts payable</span></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20190630" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:TradeAndOtherCurrentPayablesToTradeSuppliers" scale="3" unitref="TWD">31,802,685</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20181231" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:TradeAndOtherCurrentPayablesToTradeSuppliers" scale="3" unitref="TWD">32,980,933</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20180630" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:TradeAndOtherCurrentPayablesToTradeSuppliers" scale="3" unitref="TWD">29,711,846</ix:nonfraction> </pre></td>
# </tr>
# <tr>
# <td style="text-align:center">2180</td>
# <td><span class="zh">　　　應付帳款－關係人</span><span class="en">　　　Accounts payable to related parties</span></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20190630" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:TradeAndOtherCurrentPayablesToRelatedParties" scale="3" unitref="TWD">767,451</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20181231" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:TradeAndOtherCurrentPayablesToRelatedParties" scale="3" unitref="TWD">1,376,499</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20180630" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:TradeAndOtherCurrentPayablesToRelatedParties" scale="3" unitref="TWD">951,332</ix:nonfraction> </pre></td>
# </tr>
# <tr>
# <td style="text-align:center">2200</td>
# <td><span class="zh">　　　其他應付款</span><span class="en">　　　Other payables</span></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20190630" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:OtherCurrentPayables" scale="3" unitref="TWD">373,177,143</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20181231" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:OtherCurrentPayables" scale="3" unitref="TWD">81,586,185</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20180630" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:OtherCurrentPayables" scale="3" unitref="TWD">291,631,390</ix:nonfraction> </pre></td>
# </tr>
# <tr>
# <td style="text-align:center">2201</td>
# <td><span class="zh">　　　　應付薪資</span><span class="en">　　　　Wages and salaries payable</span></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20190630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-bsci-ci:WagesAndSalariesPayable" scale="3" unitref="TWD">10,130,299</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20181231" decimals="-3" format="ixt:numdotdecimal" name="tifrs-bsci-ci:WagesAndSalariesPayable" scale="3" unitref="TWD">14,471,372</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20180630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-bsci-ci:WagesAndSalariesPayable" scale="3" unitref="TWD">10,047,025</ix:nonfraction> </pre></td>
# </tr>
# <tr>
# <td style="text-align:center">2206</td>
# <td><span class="zh">　　　　應付員工紅利</span><span class="en">　　　　Employee bonus payable</span></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20190630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-bsci-ci:EmployeeBonusPayable" scale="3" unitref="TWD">32,151,668</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20181231" decimals="-3" format="ixt:numdotdecimal" name="tifrs-bsci-ci:EmployeeBonusPayable" scale="3" unitref="TWD">23,631,882</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20180630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-bsci-ci:EmployeeBonusPayable" scale="3" unitref="TWD">33,915,359</ix:nonfraction> </pre></td>
# </tr>
# <tr>
# <td style="text-align:center">2207</td>
# <td><span class="zh">　　　　應付董監事酬勞</span><span class="en">　　　　Compensation due to directors and supervisors</span></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20190630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-bsci-ci:CompensationDueToDirectorsAndSupervisors" scale="3" unitref="TWD">486,382</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20181231" decimals="-3" format="ixt:numdotdecimal" name="tifrs-bsci-ci:CompensationDueToDirectorsAndSupervisors" scale="3" unitref="TWD">349,272</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20180630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-bsci-ci:CompensationDueToDirectorsAndSupervisors" scale="3" unitref="TWD">547,164</ix:nonfraction> </pre></td>
# </tr>
# <tr>
# <td style="text-align:center">2213</td>
# <td><span class="zh">　　　　應付設備款</span><span class="en">　　　　Payable on machinery and equipment</span></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20190630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-bsci-ci:PayableOnMachineryAndEquipment" scale="3" unitref="TWD">71,028,923</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20181231" decimals="-3" format="ixt:numdotdecimal" name="tifrs-bsci-ci:PayableOnMachineryAndEquipment" scale="3" unitref="TWD">43,133,659</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20180630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-bsci-ci:PayableOnMachineryAndEquipment" scale="3" unitref="TWD">39,602,732</ix:nonfraction> </pre></td>
# </tr>
# <tr>
# <td style="text-align:center">2216</td>
# <td><span class="zh">　　　　應付股利</span><span class="en">　　　　Dividends payable, non-cash assets distributions</span></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20190630" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:CurrentDividendPayables" scale="3" unitref="TWD">259,379,871</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20181231" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:CurrentDividendPayables" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20180630" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:CurrentDividendPayables" scale="3" unitref="TWD">207,519,110</ix:nonfraction> </pre></td>
# </tr>
# <tr>
# <td style="text-align:center">2230</td>
# <td><span class="zh">　　　本期所得稅負債</span><span class="en">　　　Current tax liabilities</span></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20190630" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:CurrentTaxLiabilities" scale="3" unitref="TWD">22,068,494</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20181231" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:CurrentTaxLiabilities" scale="3" unitref="TWD">38,987,053</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20180630" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:CurrentTaxLiabilities" scale="3" unitref="TWD">28,789,175</ix:nonfraction> </pre></td>
# </tr>
# <tr>
# <td style="text-align:center">2300</td>
# <td><span class="zh">　　　其他流動負債</span><span class="en">　　　Other current liabilities</span></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20190630" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:OtherCurrentLiabilities" scale="3" unitref="TWD">116,114,176</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20181231" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:OtherCurrentLiabilities" scale="3" unitref="TWD">96,660,619</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20180630" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:OtherCurrentLiabilities" scale="3" unitref="TWD">79,989,684</ix:nonfraction> </pre></td>
# </tr>
# <tr>
# <td style="text-align:center">2320</td>
# <td><span class="zh">　　　　一年或一營業週期內到期長期負債</span><span class="en">　　　　Long-term liabilities, current portion</span></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20190630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-bsci-ci:LongtermLiabilitiesCurrentPortion" scale="3" unitref="TWD">48,100,000</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20181231" decimals="-3" format="ixt:numdotdecimal" name="tifrs-bsci-ci:LongtermLiabilitiesCurrentPortion" scale="3" unitref="TWD">34,900,000</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20180630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-bsci-ci:LongtermLiabilitiesCurrentPortion" scale="3" unitref="TWD">15,900,000</ix:nonfraction> </pre></td>
# </tr>
# <tr>
# <td style="text-align:center">2399</td>
# <td><span class="zh">　　　　其他流動負債－其他</span><span class="en">　　　　Other current liabilities, others</span></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20190630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-bsci-ci:OtherCurrentLiabilitiesOthers" scale="3" unitref="TWD">68,014,176</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20181231" decimals="-3" format="ixt:numdotdecimal" name="tifrs-bsci-ci:OtherCurrentLiabilitiesOthers" scale="3" unitref="TWD">61,760,619</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20180630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-bsci-ci:OtherCurrentLiabilitiesOthers" scale="3" unitref="TWD">64,089,684</ix:nonfraction> </pre></td>
# </tr>
# <tr>
# <td style="text-align:center">21XX</td>
# <td><span class="zh">　　　流動負債合計</span><span class="en">　　　Total current liabilities</span></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20190630" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:CurrentLiabilities" scale="3" unitref="TWD">622,256,378</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20181231" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:CurrentLiabilities" scale="3" unitref="TWD">340,542,586</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20180630" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:CurrentLiabilities" scale="3" unitref="TWD">462,997,164</ix:nonfraction> </pre></td>
# </tr>
# <tr>
# <td style="text-align:center"></td>
# <td><span class="zh">　　非流動負債</span><span class="en">　　Non-current liabilities</span></td>
# <td class="amt"></td>
# <td class="amt"></td>
# <td class="amt"></td>
# </tr>
# <tr>
# <td style="text-align:center">2530</td>
# <td><span class="zh">　　　應付公司債</span><span class="en">　　　Bonds payable</span></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20190630" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:NoncurrentPortionOfNoncurrentBondsIssued" scale="3" unitref="TWD">35,300,000</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20181231" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:NoncurrentPortionOfNoncurrentBondsIssued" scale="3" unitref="TWD">56,900,000</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20180630" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:NoncurrentPortionOfNoncurrentBondsIssued" scale="3" unitref="TWD">83,400,000</ix:nonfraction> </pre></td>
# </tr>
# <tr>
# <td style="text-align:center">2570</td>
# <td><span class="zh">　　　遞延所得稅負債</span><span class="en">　　　Deferred tax liabilities</span></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20190630" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:DeferredTaxLiabilities" scale="3" unitref="TWD">147,176</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20181231" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:DeferredTaxLiabilities" scale="3" unitref="TWD">233,284</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20180630" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:DeferredTaxLiabilities" scale="3" unitref="TWD">242,158</ix:nonfraction> </pre></td>
# </tr>
# <tr>
# <td style="text-align:center">2580</td>
# <td><span class="zh">　　　租賃負債－非流動</span><span class="en">　　　Non-current lease liabilities</span></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20190630" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:NoncurrentFinanceLeaseLiabilities" scale="3" unitref="TWD">15,405,489</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20181231" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:NoncurrentFinanceLeaseLiabilities" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20180630" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:NoncurrentFinanceLeaseLiabilities" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>
# </tr>
# <tr>
# <td style="text-align:center">2600</td>
# <td><span class="zh">　　　其他非流動負債</span><span class="en">　　　Other non-current liabilities</span></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20190630" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:OtherNoncurrentLiabilities" scale="3" unitref="TWD">11,813,101</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20181231" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:OtherNoncurrentLiabilities" scale="3" unitref="TWD">14,955,772</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20180630" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:OtherNoncurrentLiabilities" scale="3" unitref="TWD">16,138,347</ix:nonfraction> </pre></td>
# </tr>
# <tr>
# <td style="text-align:center">2640</td>
# <td><span class="zh">　　　　淨確定福利負債-非流動</span><span class="en">　　　　Net defined benefit liability, non-current</span></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20190630" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:NoncurrentRecognisedLiabilitiesDefinedBenefitPlan" scale="3" unitref="TWD">9,400,580</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20181231" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:NoncurrentRecognisedLiabilitiesDefinedBenefitPlan" scale="3" unitref="TWD">9,651,405</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20180630" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:NoncurrentRecognisedLiabilitiesDefinedBenefitPlan" scale="3" unitref="TWD">8,765,705</ix:nonfraction> </pre></td>
# </tr>
# <tr>
# <td style="text-align:center">2645</td>
# <td><span class="zh">　　　　存入保證金</span><span class="en">　　　　Guarantee deposits received</span></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20190630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-bsci-ci:GuaranteeDepositsReceived" scale="3" unitref="TWD">210,970</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20181231" decimals="-3" format="ixt:numdotdecimal" name="tifrs-bsci-ci:GuaranteeDepositsReceived" scale="3" unitref="TWD">3,353,378</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20180630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-bsci-ci:GuaranteeDepositsReceived" scale="3" unitref="TWD">5,365,159</ix:nonfraction> </pre></td>
# </tr>
# <tr>
# <td style="text-align:center">2670</td>
# <td><span class="zh">　　　　其他非流動負債－其他</span><span class="en">　　　　Other non-current liabilities, others</span></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20190630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-bsci-ci:OtherNoncurrentLiabilitiesOthers" scale="3" unitref="TWD">2,201,551</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20181231" decimals="-3" format="ixt:numdotdecimal" name="tifrs-bsci-ci:OtherNoncurrentLiabilitiesOthers" scale="3" unitref="TWD">1,950,989</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20180630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-bsci-ci:OtherNoncurrentLiabilitiesOthers" scale="3" unitref="TWD">2,007,483</ix:nonfraction> </pre></td>
# </tr>
# <tr>
# <td style="text-align:center">25XX</td>
# <td><span class="zh">　　　非流動負債合計</span><span class="en">　　　Total non-current liabilities</span></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20190630" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:NoncurrentLiabilities" scale="3" unitref="TWD">62,665,766</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20181231" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:NoncurrentLiabilities" scale="3" unitref="TWD">72,089,056</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20180630" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:NoncurrentLiabilities" scale="3" unitref="TWD">99,780,505</ix:nonfraction> </pre></td>
# </tr>
# <tr>
# <td style="text-align:center">2XXX</td>
# <td><span class="zh">　　負債總計</span><span class="en">　　Total liabilities</span></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20190630" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:Liabilities" scale="3" unitref="TWD">684,922,144</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20181231" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:Liabilities" scale="3" unitref="TWD">412,631,642</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20180630" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:Liabilities" scale="3" unitref="TWD">562,777,669</ix:nonfraction> </pre></td>
# </tr>
# <tr>
# <td style="text-align:center"></td>
# <td><span class="zh">　權益</span><span class="en">　Equity</span></td>
# <td class="amt"></td>
# <td class="amt"></td>
# <td class="amt"></td>
# </tr>
# <tr>
# <td style="text-align:center"></td>
# <td><span class="zh">　　歸屬於母公司業主之權益</span><span class="en">　　Equity attributable to owners of parent</span></td>
# <td class="amt"></td>
# <td class="amt"></td>
# <td class="amt"></td>
# </tr>
# <tr>
# <td style="text-align:center"></td>
# <td><span class="zh">　　　股本</span><span class="en">　　　Share capital</span></td>
# <td class="amt"></td>
# <td class="amt"></td>
# <td class="amt"></td>
# </tr>
# <tr>
# <td style="text-align:center">3110</td>
# <td><span class="zh">　　　　普通股股本</span><span class="en">　　　　Ordinary share</span></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20190630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-bsci-ci:OrdinaryShare" scale="3" unitref="TWD">259,303,805</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20181231" decimals="-3" format="ixt:numdotdecimal" name="tifrs-bsci-ci:OrdinaryShare" scale="3" unitref="TWD">259,303,805</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20180630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-bsci-ci:OrdinaryShare" scale="3" unitref="TWD">259,303,805</ix:nonfraction> </pre></td>
# </tr>
# <tr>
# <td style="text-align:center">3100</td>
# <td><span class="zh">　　　　股本合計</span><span class="en">　　　　Total capital stock</span></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20190630" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:IssuedCapital" scale="3" unitref="TWD">259,303,805</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20181231" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:IssuedCapital" scale="3" unitref="TWD">259,303,805</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20180630" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:IssuedCapital" scale="3" unitref="TWD">259,303,805</ix:nonfraction> </pre></td>
# </tr>
# <tr>
# <td style="text-align:center"></td>
# <td><span class="zh">　　　資本公積</span><span class="en">　　　Capital surplus</span></td>
# <td class="amt"></td>
# <td class="amt"></td>
# <td class="amt"></td>
# </tr>
# <tr>
# <td style="text-align:center">3210</td>
# <td><span class="zh">　　　　資本公積－發行溢價</span><span class="en">　　　　Capital surplus, additional paid-in capital</span></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20190630" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:AdditionalPaidinCapital" scale="3" unitref="TWD">33,077,786</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20181231" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:AdditionalPaidinCapital" scale="3" unitref="TWD">33,077,786</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20180630" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:AdditionalPaidinCapital" scale="3" unitref="TWD">33,077,786</ix:nonfraction> </pre></td>
# </tr>
# <tr>
# <td style="text-align:center">3211</td>
# <td><span class="zh">　　　　　資本公積－普通股股票溢價</span><span class="en">　　　　　Capital surplus, additional paid-in capital arising from ordinary share</span></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20190630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-bsci-ci:CapitalSurplusAdditionalPaidInCapitalArisingFromOrdinaryShare" scale="3" unitref="TWD">24,184,939</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20181231" decimals="-3" format="ixt:numdotdecimal" name="tifrs-bsci-ci:CapitalSurplusAdditionalPaidInCapitalArisingFromOrdinaryShare" scale="3" unitref="TWD">24,184,939</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20180630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-bsci-ci:CapitalSurplusAdditionalPaidInCapitalArisingFromOrdinaryShare" scale="3" unitref="TWD">24,184,939</ix:nonfraction> </pre></td>
# </tr>
# <tr>
# <td style="text-align:center">3213</td>
# <td><span class="zh">　　　　　資本公積－轉換公司債轉換溢價</span><span class="en">　　　　　Capital surplus, additional paid-in capital arising from bond conversion</span></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20190630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-bsci-ci:CapitalSurplusAdditionalPaidInCapitalArisingFromBondConversion" scale="3" unitref="TWD">8,892,847</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20181231" decimals="-3" format="ixt:numdotdecimal" name="tifrs-bsci-ci:CapitalSurplusAdditionalPaidInCapitalArisingFromBondConversion" scale="3" unitref="TWD">8,892,847</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20180630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-bsci-ci:CapitalSurplusAdditionalPaidInCapitalArisingFromBondConversion" scale="3" unitref="TWD">8,892,847</ix:nonfraction> </pre></td>
# </tr>
# <tr>
# <td style="text-align:center">3235</td>
# <td><span class="zh">　　　　資本公積－認列對子公司所有權權益變動數</span><span class="en">　　　　Capital Surplus, changes in ownership interests in subsidiaries</span></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20190630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-bsci-ci:CapitalSurplusChangesInOwnershipInterestsInSubsidiaries" scale="3" unitref="TWD">121,843</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20181231" decimals="-3" format="ixt:numdotdecimal" name="tifrs-bsci-ci:CapitalSurplusChangesInOwnershipInterestsInSubsidiaries" scale="3" unitref="TWD">121,473</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="AsOf20180630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-bsci-ci:CapitalSurplusChangesInOwnershipInterestsInSubsidiaries" scale="3" unitref="TWD">118,792</ix:nonfraction> </pre></td>
# </tr>
# <tr>
# <td style="text-align:center">3250</td>
# <td><span class="zh">　　　　資本公積－受贈資產</span><span class="en">　　　　Capital surplus, donated assets received</span></td>
# ...
# </tr>
# <tr>
# <td>N7102</td>
# <td>　　　 按攤銷後成本衡量之金融資產利息收入</td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190401To20190630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-notes:InterestIncomeFromFinancialAssetsMeasuredAtAmortisedCost_n" scale="3" unitref="TWD">232,932</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20180401To20180630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-notes:InterestIncomeFromFinancialAssetsMeasuredAtAmortisedCost_n" scale="3" unitref="TWD">216,256</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-notes:InterestIncomeFromFinancialAssetsMeasuredAtAmortisedCost_n" scale="3" unitref="TWD">519,903</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20180101To20180630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-notes:InterestIncomeFromFinancialAssetsMeasuredAtAmortisedCost_n" scale="3" unitref="TWD">454,075</ix:nonfraction> </pre></td>
# </tr>
# <tr>
# <td>N7105</td>
# <td>　　　 其他利息收入</td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190401To20190630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-notes:OtherInterestIncome_n" scale="3" unitref="TWD">137,765</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20180401To20180630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-notes:OtherInterestIncome_n" scale="3" unitref="TWD">22,197</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-notes:OtherInterestIncome_n" scale="3" unitref="TWD">324,082</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20180101To20180630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-notes:OtherInterestIncome_n" scale="3" unitref="TWD">52,933</ix:nonfraction> </pre></td>
# </tr>
# <tr>
# <td>N7106</td>
# <td>　　　 透過其他綜合損益按公允價值衡量之金融資產利息收入</td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190401To20190630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-notes:InterestIncomeFromFinancialAssetsMeasuredAtFairValueThroughOtherComprehensiveIncome_n" scale="3" unitref="TWD">802,130</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20180401To20180630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-notes:InterestIncomeFromFinancialAssetsMeasuredAtFairValueThroughOtherComprehensiveIncome_n" scale="3" unitref="TWD">842,003</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-notes:InterestIncomeFromFinancialAssetsMeasuredAtFairValueThroughOtherComprehensiveIncome_n" scale="3" unitref="TWD">1,587,346</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20180101To20180630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-notes:InterestIncomeFromFinancialAssetsMeasuredAtFairValueThroughOtherComprehensiveIncome_n" scale="3" unitref="TWD">1,553,810</ix:nonfraction> </pre></td>
# </tr>
# <tr>
# <td>N7100</td>
# <td>　　　 利息收入合計</td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190401To20190630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-notes:InterestIncome_n" scale="3" unitref="TWD">4,546,917</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20180401To20180630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-notes:InterestIncome_n" scale="3" unitref="TWD">3,571,930</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-notes:InterestIncome_n" scale="3" unitref="TWD">8,955,693</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20180101To20180630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-notes:InterestIncome_n" scale="3" unitref="TWD">6,726,119</ix:nonfraction> </pre></td>
# </tr>
# <tr>
# <td>N7130</td>
# <td>　　 股利收入</td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190401To20190630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-notes:DividendIncome_n" scale="3" unitref="TWD">244,430</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20180401To20180630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-notes:DividendIncome_n" scale="3" unitref="TWD">157,905</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-notes:DividendIncome_n" scale="3" unitref="TWD">244,430</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20180101To20180630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-notes:DividendIncome_n" scale="3" unitref="TWD">158,358</ix:nonfraction> </pre></td>
# </tr>
# <tr>
# <td>N7010</td>
# <td>　　 其他收入合計</td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190401To20190630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-notes:OtherIncome_n" scale="3" unitref="TWD">4,791,347</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20180401To20180630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-notes:OtherIncome_n" scale="3" unitref="TWD">3,729,835</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-notes:OtherIncome_n" scale="3" unitref="TWD">9,200,123</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20180101To20180630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-notes:OtherIncome_n" scale="3" unitref="TWD">6,884,477</ix:nonfraction> </pre></td>
# </tr>
# </table>, <table style="width:90%">
# <tr>
# <th colspan="6" style="text-align:left">　 其他利益及損失</th>
# </tr>
# <tr>
# <th style="text-align:center">代號</th>
# <th style="text-align:center">會計項目</th>
# <th style="text-align:center">2019年4月1日至6月30日</th>
# <th style="text-align:center">2018年4月1日至6月30日</th>
# <th style="text-align:center">2019年1月1日至6月30日</th>
# <th style="text-align:center">2018年1月1日至6月30日</th>
# </tr> <tr>
# <td>N7225</td>
# <td>　　 處分投資利益(損失)</td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190401To20190630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-notes:GainsLossesOnDisposalsOfInvestments_n" scale="3" unitref="TWD">225,570</ix:nonfraction> </pre></td>
# <td class="amt"><pre>(<ix:nonfraction contextref="From20180401To20180630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-notes:GainsLossesOnDisposalsOfInvestments_n" scale="3" sign="-" unitref="TWD">259,939</ix:nonfraction>)</pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-notes:GainsLossesOnDisposalsOfInvestments_n" scale="3" unitref="TWD">167,867</ix:nonfraction> </pre></td>
# <td class="amt"><pre>(<ix:nonfraction contextref="From20180101To20180630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-notes:GainsLossesOnDisposalsOfInvestments_n" scale="3" sign="-" unitref="TWD">512,267</ix:nonfraction>)</pre></td>
# </tr>
# <tr>
# <td>N7230</td>
# <td>　　 外幣兌換利益(損失)</td>
# <td class="amt"><pre>(<ix:nonfraction contextref="From20190401To20190630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-notes:ForeignExchangeGainsLosses_n" scale="3" sign="-" unitref="TWD">738,611</ix:nonfraction>)</pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20180401To20180630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-notes:ForeignExchangeGainsLosses_n" scale="3" unitref="TWD">2,330,616</ix:nonfraction> </pre></td>
# <td class="amt"><pre>(<ix:nonfraction contextref="From20190101To20190630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-notes:ForeignExchangeGainsLosses_n" scale="3" sign="-" unitref="TWD">507,929</ix:nonfraction>)</pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20180101To20180630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-notes:ForeignExchangeGainsLosses_n" scale="3" unitref="TWD">1,653,636</ix:nonfraction> </pre></td>
# </tr>
# <tr>
# <td>N7235</td>
# <td>　　 透過損益按公允價值衡量之金融資產(負債)利益(損失)</td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190401To20190630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-notes:GainsLossesOnFinancialAssetsOrLiabilitiesAtFairValueThroughProfitOrLoss_n" scale="3" unitref="TWD">139,839</ix:nonfraction> </pre></td>
# <td class="amt"><pre>(<ix:nonfraction contextref="From20180401To20180630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-notes:GainsLossesOnFinancialAssetsOrLiabilitiesAtFairValueThroughProfitOrLoss_n" scale="3" sign="-" unitref="TWD">2,393,628</ix:nonfraction>)</pre></td>
# <td class="amt"><pre>(<ix:nonfraction contextref="From20190101To20190630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-notes:GainsLossesOnFinancialAssetsOrLiabilitiesAtFairValueThroughProfitOrLoss_n" scale="3" sign="-" unitref="TWD">356,924</ix:nonfraction>)</pre></td>
# <td class="amt"><pre>(<ix:nonfraction contextref="From20180101To20180630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-notes:GainsLossesOnFinancialAssetsOrLiabilitiesAtFairValueThroughProfitOrLoss_n" scale="3" sign="-" unitref="TWD">1,284,918</ix:nonfraction>)</pre></td>
# </tr>
# <tr>
# <td></td>
# <td>　　 減損迴轉利益(損失)</td>
# <td class="amt"></td>
# <td class="amt"></td>
# <td class="amt"></td>
# <td class="amt"></td>
# </tr>
# <tr>
# <td>N7271</td>
# <td>　　　 金融資產減損迴轉利益(損失)</td>
# <td class="amt"><pre>(<ix:nonfraction contextref="From20190401To20190630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-notes:ReversalOfImpairmentLossImpairmentLossRecognisedInProfitOrLossFinancialAssets_n" scale="3" sign="-" unitref="TWD">3,898</ix:nonfraction>)</pre></td>
# <td class="amt"><pre>(<ix:nonfraction contextref="From20180401To20180630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-notes:ReversalOfImpairmentLossImpairmentLossRecognisedInProfitOrLossFinancialAssets_n" scale="3" sign="-" unitref="TWD">304</ix:nonfraction>)</pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-notes:ReversalOfImpairmentLossImpairmentLossRecognisedInProfitOrLossFinancialAssets_n" scale="3" unitref="TWD">987</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20180101To20180630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-notes:ReversalOfImpairmentLossImpairmentLossRecognisedInProfitOrLossFinancialAssets_n" scale="3" unitref="TWD">1,453</ix:nonfraction> </pre></td>
# </tr>
# <tr>
# <td>N7270</td>
# <td>　　　 減損迴轉利益(損失)合計</td>
# <td class="amt"><pre>(<ix:nonfraction contextref="From20190401To20190630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-notes:ReversalOfImpairmentLossImpairmentLossRecognisedInProfitOrLoss_n" scale="3" sign="-" unitref="TWD">3,898</ix:nonfraction>)</pre></td>
# <td class="amt"><pre>(<ix:nonfraction contextref="From20180401To20180630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-notes:ReversalOfImpairmentLossImpairmentLossRecognisedInProfitOrLoss_n" scale="3" sign="-" unitref="TWD">304</ix:nonfraction>)</pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-notes:ReversalOfImpairmentLossImpairmentLossRecognisedInProfitOrLoss_n" scale="3" unitref="TWD">987</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20180101To20180630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-notes:ReversalOfImpairmentLossImpairmentLossRecognisedInProfitOrLoss_n" scale="3" unitref="TWD">1,453</ix:nonfraction> </pre></td>
# </tr>
# <tr>
# <td>N7600</td>
# <td>　　 其他利益及損失</td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190401To20190630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-notes:OtherGainsAndLossesOthers_n" scale="3" unitref="TWD">63,356</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20180401To20180630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-notes:OtherGainsAndLossesOthers_n" scale="3" unitref="TWD">114,673</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-notes:OtherGainsAndLossesOthers_n" scale="3" unitref="TWD">354,682</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20180101To20180630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-notes:OtherGainsAndLossesOthers_n" scale="3" unitref="TWD">21,722</ix:nonfraction> </pre></td>
# </tr>
# <tr>
# <td>N7020</td>
# <td>　　 其他利益及損失淨額</td>
# <td class="amt"><pre>(<ix:nonfraction contextref="From20190401To20190630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-notes:OtherGainsAndLosses_n" scale="3" sign="-" unitref="TWD">313,744</ix:nonfraction>)</pre></td>
# <td class="amt"><pre>(<ix:nonfraction contextref="From20180401To20180630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-notes:OtherGainsAndLosses_n" scale="3" sign="-" unitref="TWD">208,582</ix:nonfraction>)</pre></td>
# <td class="amt"><pre>(<ix:nonfraction contextref="From20190101To20190630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-notes:OtherGainsAndLosses_n" scale="3" sign="-" unitref="TWD">341,317</ix:nonfraction>)</pre></td>
# <td class="amt"><pre>(<ix:nonfraction contextref="From20180101To20180630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-notes:OtherGainsAndLosses_n" scale="3" sign="-" unitref="TWD">120,374</ix:nonfraction>)</pre></td>
# </tr>
# </table>, <table style="width:90%">
# <tr>
# <th colspan="6" style="text-align:left">　 財務成本</th>
# </tr>
# <tr>
# <th style="text-align:center">代號</th>
# <th style="text-align:center">會計項目</th>
# <th style="text-align:center">2019年4月1日至6月30日</th>
# <th style="text-align:center">2018年4月1日至6月30日</th>
# <th style="text-align:center">2019年1月1日至6月30日</th>
# <th style="text-align:center">2018年1月1日至6月30日</th>
# </tr>
# <tr>
# <td>N7510</td>
# <td>　　 利息費用</td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190401To20190630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-notes:InterestExpense_n" scale="3" unitref="TWD">864,751</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20180401To20180630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-notes:InterestExpense_n" scale="3" unitref="TWD">628,284</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-notes:InterestExpense_n" scale="3" unitref="TWD">1,763,816</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20180101To20180630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-notes:InterestExpense_n" scale="3" unitref="TWD">1,436,250</ix:nonfraction> </pre></td>
# </tr>
# <tr>
# <td>N7050</td>
# <td>　　 財務成本淨額</td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190401To20190630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-notes:FinanceCosts_n" scale="3" unitref="TWD">864,751</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20180401To20180630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-notes:FinanceCosts_n" scale="3" unitref="TWD">628,284</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-notes:FinanceCosts_n" scale="3" unitref="TWD">1,763,816</ix:nonfraction> </pre></td>
# <td class="amt"><pre><ix:nonfraction contextref="From20180101To20180630" decimals="-3" format="ixt:numdotdecimal" name="tifrs-notes:FinanceCosts_n" scale="3" unitref="TWD">1,436,250</ix:nonfraction> </pre></td>
# </tr>
# </table>]

# %%
Ntable = 0
start = 6
k = 3

code = tables[Ntable].select('td')

code_list=[]

for _code in code:
    try:
        if (_code['style'])!='':
            code_list.append(_code.text)
    except:
        pass
#print(code_list)

cht = tables[Ntable].select('span.zh')
en = tables[Ntable].select('span.en')
amt = tables[Ntable].select('td.amt')

#print(code)

#print(len(cht[start:]), len(amt)/k)

#df_cht, df_eng = {} , {}
Balance_list=[]
j=0
for i, _amt in enumerate(amt):
    
    if i%k==0:
        #print(i, _amt.text)
        #balance_list[code_list[j]]= [{'cht':cht[6+j].text.strip(),'value':_amt.text.strip().replace(',','')}]
        Balance_list.append([{'code':code_list[j], 'en':en[start+j].text.strip(), 'cht':cht[start+j].text.strip()
                              ,'value':_amt.text.strip().replace(',','')}])
        j+=1

Balance={'Balance':balance_list}        
#print(Balance)

# %%
Ntable = 1
k = 4
start=7


code = tables[Ntable].select('td')

code_list=[]

for _code in code:
    try:
        if (_code['style'])!='':
            code_list.append(_code.text)
    except:
        pass
#print(code_list)

cht = tables[Ntable].select('span.zh')
en = tables[Ntable].select('span.en')
amt = tables[Ntable].select('td.amt')

#print(code)

#print(len(cht[7:]), len(amt)/4)

ProfitLoss_list=[]
j=0
for i, _amt in enumerate(amt):
    
    if i%4==0:
        ProfitLoss_list.append([{'code':code_list[j], 'en':en[start+j].text.strip(), 'cht':cht[start+j].text.strip(),
                              'value':_amt.text.strip().replace(',','')}])
        j+=1

ProfitLoss={'ProfitLoss':profit_loss_list}        
#print(ProfitLoss)

# %%
Ntable = 2
start=5
k=2


code = tables[Ntable].select('td')


code_list=[]

for _code in code:
    try:
        if (_code['style'])!='':
            code_list.append(_code.text)
    except:
        pass
#print(code_list)

cht = tables[Ntable].select('span.zh')
en = tables[Ntable].select('span.en')
amt = tables[Ntable].select('td.amt')

#print(code)

#print(len(cht[start:]), len(amt)/2)

CashFlows_list=[]
j=0
for i, _amt in enumerate(amt):
    
    if i%k==0:
        CashFlows_list.append([{'code':code_list[j], 'en':en[start+j].text.strip(), 'cht':cht[start+j].text.strip(),
                              'value':_amt.text.strip().replace(',','')}])
        j+=1

CashFlows={'CashFlows':CashFlows_list}        
#print(CashFlows)

# %%
Ntable = 3
start=5
k=2


code = tables[Ntable].select('td')

print(code)

#code_list=[]

for _code in code:
    try:
        if (_code['style'])!='':
            code_list.append(_code.text)
    except:
        pass
#print(code_list)

cht = tables[Ntable].select('span.zh')
en = tables[Ntable].select('span.en')
amt = tables[Ntable].select('td.amt')

#print(code)

#print(len(cht[start:]), len(amt)/2)

Equity_list=[]
j=0
for i, _amt in enumerate(amt):
    
    if i%k==0:
        Equity_list.append([{'code':code_list[j], 'en':en[start+j].text.strip(), 'cht':cht[start+j].text.strip(),
                                'value':_amt.text.strip().replace(',','')}])
        j+=1

Equity ={'Equity ':cash_flow_list}        
#print(Equity )
# Out:
# [<td>A1</td>, <td>
# <span class="zh">期初餘額</span>
# <span class="en">　Equity at beginning of period</span>
# </td>, <td class="amt"><pre><ix:nonfraction contextref="AsOf20190101_OrdinaryShareMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:Equity" scale="3" unitref="TWD">259,303,805</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="AsOf20190101_IssuedCapitalMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:Equity" scale="3" unitref="TWD">259,303,805</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="AsOf20190101_CapitalReserveMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:Equity" scale="3" unitref="TWD">56,315,932</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="AsOf20190101_StatutoryReserveMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:Equity" scale="3" unitref="TWD">276,033,811</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="AsOf20190101_SpecialReserveMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:Equity" scale="3" unitref="TWD">26,907,527</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="AsOf20190101_UnappropriatedRetainedEarningsAccumulatedDeficitMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:Equity" scale="3" unitref="TWD">1,073,706,503</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="AsOf20190101_RetainedEarningsMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:Equity" scale="3" unitref="TWD">1,376,647,841</ix:nonfraction> </pre></td>, <td class="amt"><pre>(<ix:nonfraction contextref="AsOf20190101_ReserveOfExchangeDifferencesOnTranslationMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:Equity" scale="3" sign="-" unitref="TWD">12,042,347</ix:nonfraction>)</pre></td>, <td class="amt"><pre>(<ix:nonfraction contextref="AsOf20190101_ReserveOfGainsAndLossesOnFinancialAssetsMeasuredAtFairValueThroughOtherComprehensiveIncomeMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:Equity" scale="3" sign="-" unitref="TWD">3,429,324</ix:nonfraction>)</pre></td>, <td class="amt"><pre><ix:nonfraction contextref="AsOf20190101_GainsLossesOnHedgingInstrumentsMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:Equity" scale="3" unitref="TWD">23,601</ix:nonfraction> </pre></td>, <td class="amt"><pre>(<ix:nonfraction contextref="AsOf20190101_Others-OtherEquityInterestMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:Equity" scale="3" sign="-" unitref="TWD">1,843</ix:nonfraction>)</pre></td>, <td class="amt"><pre>(<ix:nonfraction contextref="AsOf20190101_OtherEquityInterestMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:Equity" scale="3" sign="-" unitref="TWD">15,449,913</ix:nonfraction>)</pre></td>, <td class="amt"><pre><ix:nonfraction contextref="AsOf20190101_EquityAttributableToOwnersOfParentMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:Equity" scale="3" unitref="TWD">1,676,817,665</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="AsOf20190101_NoncontrollingInterestsMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:Equity" scale="3" unitref="TWD">678,731</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="AsOf20190101_TotalEquityMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:Equity" scale="3" unitref="TWD">1,677,496,396</ix:nonfraction> </pre></td>, <td>B1</td>, <td>
# <span class="zh">提列法定盈餘公積</span>
# <span class="en">　　Legal reserve appropriated</span>
# </td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_OrdinaryShareMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:LegalReserveAppropriated" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_IssuedCapitalMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:LegalReserveAppropriated" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_CapitalReserveMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:LegalReserveAppropriated" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_StatutoryReserveMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:LegalReserveAppropriated" scale="3" unitref="TWD">35,113,088</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_SpecialReserveMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:LegalReserveAppropriated" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre>(<ix:nonfraction contextref="From20190101To20190630_UnappropriatedRetainedEarningsAccumulatedDeficitMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:LegalReserveAppropriated" scale="3" sign="-" unitref="TWD">35,113,088</ix:nonfraction>)</pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_RetainedEarningsMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:LegalReserveAppropriated" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_ReserveOfExchangeDifferencesOnTranslationMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:LegalReserveAppropriated" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_ReserveOfGainsAndLossesOnFinancialAssetsMeasuredAtFairValueThroughOtherComprehensiveIncomeMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:LegalReserveAppropriated" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_GainsLossesOnHedgingInstrumentsMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:LegalReserveAppropriated" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_Others-OtherEquityInterestMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:LegalReserveAppropriated" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_OtherEquityInterestMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:LegalReserveAppropriated" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_EquityAttributableToOwnersOfParentMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:LegalReserveAppropriated" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_NoncontrollingInterestsMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:LegalReserveAppropriated" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_TotalEquityMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:LegalReserveAppropriated" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td>B3</td>, <td>
# <span class="zh">提列特別盈餘公積</span>
# <span class="en">　　Special reserve appropriated</span>
# </td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_OrdinaryShareMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:SpecialReserveAppropriated" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_IssuedCapitalMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:SpecialReserveAppropriated" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_CapitalReserveMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:SpecialReserveAppropriated" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_StatutoryReserveMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:SpecialReserveAppropriated" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre>(<ix:nonfraction contextref="From20190101To20190630_SpecialReserveMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:SpecialReserveAppropriated" scale="3" sign="-" unitref="TWD">16,183,397</ix:nonfraction>)</pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_UnappropriatedRetainedEarningsAccumulatedDeficitMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:SpecialReserveAppropriated" scale="3" unitref="TWD">16,183,397</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_RetainedEarningsMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:SpecialReserveAppropriated" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_ReserveOfExchangeDifferencesOnTranslationMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:SpecialReserveAppropriated" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_ReserveOfGainsAndLossesOnFinancialAssetsMeasuredAtFairValueThroughOtherComprehensiveIncomeMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:SpecialReserveAppropriated" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_GainsLossesOnHedgingInstrumentsMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:SpecialReserveAppropriated" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_Others-OtherEquityInterestMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:SpecialReserveAppropriated" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_OtherEquityInterestMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:SpecialReserveAppropriated" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_EquityAttributableToOwnersOfParentMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:SpecialReserveAppropriated" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_NoncontrollingInterestsMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:SpecialReserveAppropriated" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_TotalEquityMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:SpecialReserveAppropriated" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td>B5</td>, <td>
# <span class="zh">普通股現金股利</span>
# <span class="en">　　Cash dividends of ordinary share</span>
# </td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_OrdinaryShareMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:CashDividendsOfOrdinaryShare" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_IssuedCapitalMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:CashDividendsOfOrdinaryShare" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_CapitalReserveMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:CashDividendsOfOrdinaryShare" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_StatutoryReserveMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:CashDividendsOfOrdinaryShare" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_SpecialReserveMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:CashDividendsOfOrdinaryShare" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre>(<ix:nonfraction contextref="From20190101To20190630_UnappropriatedRetainedEarningsAccumulatedDeficitMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:CashDividendsOfOrdinaryShare" scale="3" sign="-" unitref="TWD">259,303,805</ix:nonfraction>)</pre></td>, <td class="amt"><pre>(<ix:nonfraction contextref="From20190101To20190630_RetainedEarningsMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:CashDividendsOfOrdinaryShare" scale="3" sign="-" unitref="TWD">259,303,805</ix:nonfraction>)</pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_ReserveOfExchangeDifferencesOnTranslationMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:CashDividendsOfOrdinaryShare" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_ReserveOfGainsAndLossesOnFinancialAssetsMeasuredAtFairValueThroughOtherComprehensiveIncomeMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:CashDividendsOfOrdinaryShare" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_GainsLossesOnHedgingInstrumentsMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:CashDividendsOfOrdinaryShare" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_Others-OtherEquityInterestMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:CashDividendsOfOrdinaryShare" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_OtherEquityInterestMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:CashDividendsOfOrdinaryShare" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre>(<ix:nonfraction contextref="From20190101To20190630_EquityAttributableToOwnersOfParentMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:CashDividendsOfOrdinaryShare" scale="3" sign="-" unitref="TWD">259,303,805</ix:nonfraction>)</pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_NoncontrollingInterestsMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:CashDividendsOfOrdinaryShare" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre>(<ix:nonfraction contextref="From20190101To20190630_TotalEquityMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:CashDividendsOfOrdinaryShare" scale="3" sign="-" unitref="TWD">259,303,805</ix:nonfraction>)</pre></td>, <td>C7</td>, <td>
# <span class="zh">採用權益法認列之關聯企業及合資之變動數</span>
# <span class="en">　　Changes in equity of associates and joint ventures accounted for using equity method</span>
# </td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_OrdinaryShareMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInEquityOfAssociatesAndJointVenturesAccountedForUsingEquityMethod" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_IssuedCapitalMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInEquityOfAssociatesAndJointVenturesAccountedForUsingEquityMethod" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_CapitalReserveMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInEquityOfAssociatesAndJointVenturesAccountedForUsingEquityMethod" scale="3" unitref="TWD">4,627</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_StatutoryReserveMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInEquityOfAssociatesAndJointVenturesAccountedForUsingEquityMethod" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_SpecialReserveMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInEquityOfAssociatesAndJointVenturesAccountedForUsingEquityMethod" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_UnappropriatedRetainedEarningsAccumulatedDeficitMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInEquityOfAssociatesAndJointVenturesAccountedForUsingEquityMethod" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_RetainedEarningsMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInEquityOfAssociatesAndJointVenturesAccountedForUsingEquityMethod" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_ReserveOfExchangeDifferencesOnTranslationMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInEquityOfAssociatesAndJointVenturesAccountedForUsingEquityMethod" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_ReserveOfGainsAndLossesOnFinancialAssetsMeasuredAtFairValueThroughOtherComprehensiveIncomeMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInEquityOfAssociatesAndJointVenturesAccountedForUsingEquityMethod" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_GainsLossesOnHedgingInstrumentsMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInEquityOfAssociatesAndJointVenturesAccountedForUsingEquityMethod" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_Others-OtherEquityInterestMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInEquityOfAssociatesAndJointVenturesAccountedForUsingEquityMethod" scale="3" unitref="TWD">1,843</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_OtherEquityInterestMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInEquityOfAssociatesAndJointVenturesAccountedForUsingEquityMethod" scale="3" unitref="TWD">1,843</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_EquityAttributableToOwnersOfParentMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInEquityOfAssociatesAndJointVenturesAccountedForUsingEquityMethod" scale="3" unitref="TWD">6,470</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_NoncontrollingInterestsMember" decimals="-3" format="ixt:numdotdecimal"  ...
# <span class="zh">本期淨利（淨損）</span>
# <span class="en">　Profit (loss)</span>
# </td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_OrdinaryShareMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ProfitLoss" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_IssuedCapitalMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ProfitLoss" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_CapitalReserveMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ProfitLoss" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_StatutoryReserveMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ProfitLoss" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_SpecialReserveMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ProfitLoss" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_UnappropriatedRetainedEarningsAccumulatedDeficitMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ProfitLoss" scale="3" unitref="TWD">128,158,701</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_RetainedEarningsMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ProfitLoss" scale="3" unitref="TWD">128,158,701</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_ReserveOfExchangeDifferencesOnTranslationMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ProfitLoss" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_ReserveOfGainsAndLossesOnFinancialAssetsMeasuredAtFairValueThroughOtherComprehensiveIncomeMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ProfitLoss" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_GainsLossesOnHedgingInstrumentsMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ProfitLoss" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_Others-OtherEquityInterestMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ProfitLoss" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_OtherEquityInterestMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ProfitLoss" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_EquityAttributableToOwnersOfParentMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ProfitLoss" scale="3" unitref="TWD">128,158,701</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_NoncontrollingInterestsMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ProfitLoss" scale="3" unitref="TWD">4,460</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_TotalEquityMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ProfitLoss" scale="3" unitref="TWD">128,163,161</ix:nonfraction> </pre></td>, <td>D3</td>, <td>
# <span class="zh">本期其他綜合損益</span>
# <span class="en">　Other comprehensive income</span>
# </td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_OrdinaryShareMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:OtherComprehensiveIncome" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_IssuedCapitalMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:OtherComprehensiveIncome" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_CapitalReserveMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:OtherComprehensiveIncome" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_StatutoryReserveMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:OtherComprehensiveIncome" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_SpecialReserveMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:OtherComprehensiveIncome" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_UnappropriatedRetainedEarningsAccumulatedDeficitMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:OtherComprehensiveIncome" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_RetainedEarningsMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:OtherComprehensiveIncome" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_ReserveOfExchangeDifferencesOnTranslationMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:OtherComprehensiveIncome" scale="3" unitref="TWD">5,533,346</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_ReserveOfGainsAndLossesOnFinancialAssetsMeasuredAtFairValueThroughOtherComprehensiveIncomeMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:OtherComprehensiveIncome" scale="3" unitref="TWD">2,596,706</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_GainsLossesOnHedgingInstrumentsMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:OtherComprehensiveIncome" scale="3" unitref="TWD">11,901</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_Others-OtherEquityInterestMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:OtherComprehensiveIncome" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_OtherEquityInterestMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:OtherComprehensiveIncome" scale="3" unitref="TWD">8,141,953</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_EquityAttributableToOwnersOfParentMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:OtherComprehensiveIncome" scale="3" unitref="TWD">8,141,953</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_NoncontrollingInterestsMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:OtherComprehensiveIncome" scale="3" unitref="TWD">53</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_TotalEquityMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:OtherComprehensiveIncome" scale="3" unitref="TWD">8,142,006</ix:nonfraction> </pre></td>, <td>D5</td>, <td>
# <span class="zh">本期綜合損益總額</span>
# <span class="en">　Total comprehensive income</span>
# </td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_OrdinaryShareMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ComprehensiveIncome" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_IssuedCapitalMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ComprehensiveIncome" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_CapitalReserveMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ComprehensiveIncome" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_StatutoryReserveMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ComprehensiveIncome" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_SpecialReserveMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ComprehensiveIncome" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_UnappropriatedRetainedEarningsAccumulatedDeficitMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ComprehensiveIncome" scale="3" unitref="TWD">128,158,701</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_RetainedEarningsMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ComprehensiveIncome" scale="3" unitref="TWD">128,158,701</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_ReserveOfExchangeDifferencesOnTranslationMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ComprehensiveIncome" scale="3" unitref="TWD">5,533,346</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_ReserveOfGainsAndLossesOnFinancialAssetsMeasuredAtFairValueThroughOtherComprehensiveIncomeMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ComprehensiveIncome" scale="3" unitref="TWD">2,596,706</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_GainsLossesOnHedgingInstrumentsMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ComprehensiveIncome" scale="3" unitref="TWD">11,901</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_Others-OtherEquityInterestMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ComprehensiveIncome" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_OtherEquityInterestMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ComprehensiveIncome" scale="3" unitref="TWD">8,141,953</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_EquityAttributableToOwnersOfParentMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ComprehensiveIncome" scale="3" unitref="TWD">136,300,654</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_NoncontrollingInterestsMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ComprehensiveIncome" scale="3" unitref="TWD">4,513</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_TotalEquityMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ComprehensiveIncome" scale="3" unitref="TWD">136,305,167</ix:nonfraction> </pre></td>, <td>M7</td>, <td>
# <span class="zh">對子公司所有權權益變動</span>
# <span class="en">　Changes in ownership interests in subsidiaries</span>
# </td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_OrdinaryShareMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInOwnershipInterestsInSubsidiaries" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_IssuedCapitalMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInOwnershipInterestsInSubsidiaries" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_CapitalReserveMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInOwnershipInterestsInSubsidiaries" scale="3" unitref="TWD">370</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_StatutoryReserveMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInOwnershipInterestsInSubsidiaries" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_SpecialReserveMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInOwnershipInterestsInSubsidiaries" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_UnappropriatedRetainedEarningsAccumulatedDeficitMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInOwnershipInterestsInSubsidiaries" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_RetainedEarningsMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInOwnershipInterestsInSubsidiaries" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_ReserveOfExchangeDifferencesOnTranslationMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInOwnershipInterestsInSubsidiaries" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_ReserveOfGainsAndLossesOnFinancialAssetsMeasuredAtFairValueThroughOtherComprehensiveIncomeMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInOwnershipInterestsInSubsidiaries" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_GainsLossesOnHedgingInstrumentsMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInOwnershipInterestsInSubsidiaries" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_Others-OtherEquityInterestMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInOwnershipInterestsInSubsidiaries" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_OtherEquityInterestMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInOwnershipInterestsInSubsidiaries" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_EquityAttributableToOwnersOfParentMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInOwnershipInterestsInSubsidiaries" scale="3" unitref="TWD">370</ix:nonfraction> </pre></td>, <td class="amt"><pre>(<ix:nonfraction contextref="From20190101To20190630_NoncontrollingInterestsMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInOwnershipInterestsInSubsidiaries" scale="3" sign="-" unitref="TWD">370</ix:nonfraction>)</pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_TotalEquityMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInOwnershipInterestsInSubsidiaries" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td>O1</td>, <td>
# <span class="zh">非控制權益增減</span>
# <span class="en">　Changes in non-controlling interests</span>
# </td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_OrdinaryShareMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInNoncontrollingInterests" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_IssuedCapitalMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInNoncontrollingInterests" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_CapitalReserveMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInNoncontrollingInterests" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_StatutoryReserveMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInNoncontrollingInterests" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_SpecialReserveMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInNoncontrollingInterests" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_UnappropriatedRetainedEarningsAccumulatedDeficitMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInNoncontrollingInterests" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_RetainedEarningsMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInNoncontrollingInterests" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_ReserveOfExchangeDifferencesOnTranslationMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInNoncontrollingInterests" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_ReserveOfGainsAndLossesOnFinancialAssetsMeasuredAtFairValueThroughOtherComprehensiveIncomeMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInNoncontrollingInterests" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_GainsLossesOnHedgingInstrumentsMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInNoncontrollingInterests" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_Others-OtherEquityInterestMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInNoncontrollingInterests" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_OtherEquityInterestMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInNoncontrollingInterests" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_EquityAttributableToOwnersOfParentMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInNoncontrollingInterests" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre>(<ix:nonfraction contextref="From20190101To20190630_NoncontrollingInterestsMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInNoncontrollingInterests" scale="3" sign="-" unitref="TWD">76,036</ix:nonfraction>)</pre></td>, <td class="amt"><pre>(<ix:nonfraction contextref="From20190101To20190630_TotalEquityMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:ChangesInNoncontrollingInterests" scale="3" sign="-" unitref="TWD">76,036</ix:nonfraction>)</pre></td>, <td>Q1</td>, <td>
# <span class="zh">處分透過其他綜合損益按公允價值衡量之權益工具</span>
# <span class="en">　Disposal of investments in equity instruments designated at fair value through other comprehensive income</span>
# </td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_OrdinaryShareMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:DisposalOfInvestmentsInEquityInstrumentsDesignatedAtFairValueThroughOtherComprehensiveIncome" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_IssuedCapitalMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:DisposalOfInvestmentsInEquityInstrumentsDesignatedAtFairValueThroughOtherComprehensiveIncome" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_CapitalReserveMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:DisposalOfInvestmentsInEquityInstrumentsDesignatedAtFairValueThroughOtherComprehensiveIncome" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_StatutoryReserveMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:DisposalOfInvestmentsInEquityInstrumentsDesignatedAtFairValueThroughOtherComprehensiveIncome" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_SpecialReserveMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:DisposalOfInvestmentsInEquityInstrumentsDesignatedAtFairValueThroughOtherComprehensiveIncome" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_UnappropriatedRetainedEarningsAccumulatedDeficitMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:DisposalOfInvestmentsInEquityInstrumentsDesignatedAtFairValueThroughOtherComprehensiveIncome" scale="3" unitref="TWD">73,048</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_RetainedEarningsMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:DisposalOfInvestmentsInEquityInstrumentsDesignatedAtFairValueThroughOtherComprehensiveIncome" scale="3" unitref="TWD">73,048</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_ReserveOfExchangeDifferencesOnTranslationMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:DisposalOfInvestmentsInEquityInstrumentsDesignatedAtFairValueThroughOtherComprehensiveIncome" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre>(<ix:nonfraction contextref="From20190101To20190630_ReserveOfGainsAndLossesOnFinancialAssetsMeasuredAtFairValueThroughOtherComprehensiveIncomeMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:DisposalOfInvestmentsInEquityInstrumentsDesignatedAtFairValueThroughOtherComprehensiveIncome" scale="3" sign="-" unitref="TWD">73,048</ix:nonfraction>)</pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_GainsLossesOnHedgingInstrumentsMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:DisposalOfInvestmentsInEquityInstrumentsDesignatedAtFairValueThroughOtherComprehensiveIncome" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_Others-OtherEquityInterestMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:DisposalOfInvestmentsInEquityInstrumentsDesignatedAtFairValueThroughOtherComprehensiveIncome" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre>(<ix:nonfraction contextref="From20190101To20190630_OtherEquityInterestMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:DisposalOfInvestmentsInEquityInstrumentsDesignatedAtFairValueThroughOtherComprehensiveIncome" scale="3" sign="-" unitref="TWD">73,048</ix:nonfraction>)</pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_EquityAttributableToOwnersOfParentMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:DisposalOf ...
# <span class="zh">其他</span>
# <span class="en">　Others</span>
# </td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_OrdinaryShareMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:Others-IncreaseDecreaseInEquity" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_IssuedCapitalMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:Others-IncreaseDecreaseInEquity" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_CapitalReserveMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:Others-IncreaseDecreaseInEquity" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_StatutoryReserveMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:Others-IncreaseDecreaseInEquity" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_SpecialReserveMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:Others-IncreaseDecreaseInEquity" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_UnappropriatedRetainedEarningsAccumulatedDeficitMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:Others-IncreaseDecreaseInEquity" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_RetainedEarningsMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:Others-IncreaseDecreaseInEquity" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_ReserveOfExchangeDifferencesOnTranslationMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:Others-IncreaseDecreaseInEquity" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_ReserveOfGainsAndLossesOnFinancialAssetsMeasuredAtFairValueThroughOtherComprehensiveIncomeMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:Others-IncreaseDecreaseInEquity" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre>(<ix:nonfraction contextref="From20190101To20190630_GainsLossesOnHedgingInstrumentsMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:Others-IncreaseDecreaseInEquity" scale="3" sign="-" unitref="TWD">6,775</ix:nonfraction>)</pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_Others-OtherEquityInterestMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:Others-IncreaseDecreaseInEquity" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre>(<ix:nonfraction contextref="From20190101To20190630_OtherEquityInterestMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:Others-IncreaseDecreaseInEquity" scale="3" sign="-" unitref="TWD">6,775</ix:nonfraction>)</pre></td>, <td class="amt"><pre>(<ix:nonfraction contextref="From20190101To20190630_EquityAttributableToOwnersOfParentMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:Others-IncreaseDecreaseInEquity" scale="3" sign="-" unitref="TWD">6,775</ix:nonfraction>)</pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_NoncontrollingInterestsMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:Others-IncreaseDecreaseInEquity" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre>(<ix:nonfraction contextref="From20190101To20190630_TotalEquityMember" decimals="-3" format="ixt:numdotdecimal" name="tifrs-es:Others-IncreaseDecreaseInEquity" scale="3" sign="-" unitref="TWD">6,775</ix:nonfraction>)</pre></td>, <td>Y1</td>, <td>
# <span class="zh">權益增加(減少)總額</span>
# <span class="en">　Total increase (decrease) in equity</span>
# </td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_OrdinaryShareMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ChangesInEquity" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_IssuedCapitalMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ChangesInEquity" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_CapitalReserveMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ChangesInEquity" scale="3" unitref="TWD">4,997</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_StatutoryReserveMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ChangesInEquity" scale="3" unitref="TWD">35,113,088</ix:nonfraction> </pre></td>, <td class="amt"><pre>(<ix:nonfraction contextref="From20190101To20190630_SpecialReserveMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ChangesInEquity" scale="3" sign="-" unitref="TWD">16,183,397</ix:nonfraction>)</pre></td>, <td class="amt"><pre>(<ix:nonfraction contextref="From20190101To20190630_UnappropriatedRetainedEarningsAccumulatedDeficitMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ChangesInEquity" scale="3" sign="-" unitref="TWD">150,001,747</ix:nonfraction>)</pre></td>, <td class="amt"><pre>(<ix:nonfraction contextref="From20190101To20190630_RetainedEarningsMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ChangesInEquity" scale="3" sign="-" unitref="TWD">131,072,056</ix:nonfraction>)</pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_ReserveOfExchangeDifferencesOnTranslationMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ChangesInEquity" scale="3" unitref="TWD">5,533,346</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_ReserveOfGainsAndLossesOnFinancialAssetsMeasuredAtFairValueThroughOtherComprehensiveIncomeMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ChangesInEquity" scale="3" unitref="TWD">2,523,658</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_GainsLossesOnHedgingInstrumentsMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ChangesInEquity" scale="3" unitref="TWD">5,126</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_Others-OtherEquityInterestMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ChangesInEquity" scale="3" unitref="TWD">1,843</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="From20190101To20190630_OtherEquityInterestMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ChangesInEquity" scale="3" unitref="TWD">8,063,973</ix:nonfraction> </pre></td>, <td class="amt"><pre>(<ix:nonfraction contextref="From20190101To20190630_EquityAttributableToOwnersOfParentMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ChangesInEquity" scale="3" sign="-" unitref="TWD">123,003,086</ix:nonfraction>)</pre></td>, <td class="amt"><pre>(<ix:nonfraction contextref="From20190101To20190630_NoncontrollingInterestsMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ChangesInEquity" scale="3" sign="-" unitref="TWD">71,783</ix:nonfraction>)</pre></td>, <td class="amt"><pre>(<ix:nonfraction contextref="From20190101To20190630_TotalEquityMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:ChangesInEquity" scale="3" sign="-" unitref="TWD">123,074,869</ix:nonfraction>)</pre></td>, <td>Z1</td>, <td>
# <span class="zh">期末餘額</span>
# <span class="en">　Equity at end of period</span>
# </td>, <td class="amt"><pre><ix:nonfraction contextref="AsOf20190630_OrdinaryShareMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:Equity" scale="3" unitref="TWD">259,303,805</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="AsOf20190630_IssuedCapitalMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:Equity" scale="3" unitref="TWD">259,303,805</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="AsOf20190630_CapitalReserveMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:Equity" scale="3" unitref="TWD">56,320,929</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="AsOf20190630_StatutoryReserveMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:Equity" scale="3" unitref="TWD">311,146,899</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="AsOf20190630_SpecialReserveMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:Equity" scale="3" unitref="TWD">10,724,130</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="AsOf20190630_UnappropriatedRetainedEarningsAccumulatedDeficitMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:Equity" scale="3" unitref="TWD">923,704,756</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="AsOf20190630_RetainedEarningsMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:Equity" scale="3" unitref="TWD">1,245,575,785</ix:nonfraction> </pre></td>, <td class="amt"><pre>(<ix:nonfraction contextref="AsOf20190630_ReserveOfExchangeDifferencesOnTranslationMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:Equity" scale="3" sign="-" unitref="TWD">6,509,001</ix:nonfraction>)</pre></td>, <td class="amt"><pre>(<ix:nonfraction contextref="AsOf20190630_ReserveOfGainsAndLossesOnFinancialAssetsMeasuredAtFairValueThroughOtherComprehensiveIncomeMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:Equity" scale="3" sign="-" unitref="TWD">905,666</ix:nonfraction>)</pre></td>, <td class="amt"><pre><ix:nonfraction contextref="AsOf20190630_GainsLossesOnHedgingInstrumentsMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:Equity" scale="3" unitref="TWD">28,727</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="AsOf20190630_Others-OtherEquityInterestMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:Equity" scale="3" unitref="TWD">0</ix:nonfraction> </pre></td>, <td class="amt"><pre>(<ix:nonfraction contextref="AsOf20190630_OtherEquityInterestMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:Equity" scale="3" sign="-" unitref="TWD">7,385,940</ix:nonfraction>)</pre></td>, <td class="amt"><pre><ix:nonfraction contextref="AsOf20190630_EquityAttributableToOwnersOfParentMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:Equity" scale="3" unitref="TWD">1,553,814,579</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="AsOf20190630_NoncontrollingInterestsMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:Equity" scale="3" unitref="TWD">606,948</ix:nonfraction> </pre></td>, <td class="amt"><pre><ix:nonfraction contextref="AsOf20190630_TotalEquityMember" decimals="-3" format="ixt:numdotdecimal" name="ifrs-full:Equity" scale="3" unitref="TWD">1,554,421,527</ix:nonfraction> </pre></td>]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-224-267014d2d87f> in <module>
#      31
#      32     if i%k==0:
# ---> 33         Equity_list.append([{'code':code_list[j], 'en':en[start+j].text.strip(), 'cht':cht[start+j].text.strip(),
#      34                                 'value':_amt.text.strip().replace(',','')}])
#      35         j+=1
#
# IndexError: list index out of range
